# %% [markdown]
# # Train the Spire

# %% [markdown]
# Final Project  <br />
# Daniel Feldman

# %% [markdown]
# **Project Decription**:

# %% [markdown]
# My goal in this project is to apply machine learning to a card game called “Slay the Spire.” This game is a deck building card game where a player must try to survive a series of combats without losing all of their health points. The final result of the project will be to create a model that given a player’s ingame progress, will be able to predict the amount of health lost in subsequent combats. This will allow the player to identify the most effective card to add to their deck at each point in the game.

# %% [markdown]
# **Data Processing**:

# %% [markdown]
# I transformed the categorical data to quantitative data using both a multi-label binarizer and a count vectorizer. I used a multi-label binarizer rather than a one-hot encoder since I needed to encode multiple labels per instance, for example each player has a set of various different relics. The multi-label binarizer allowed me to convert the relic data into a binary vector. Each position in the vector is associated with a specific relic. The value at a position represents whether the player has that specific relic: 1 means they have the relic , 0 means they do not have the relic.

# %% [markdown]
# I repeated a similar process for transforming the player cards and enemies fought, except in this case, a player may have multiple copies of the same card or may have fought the same enemy more than once. Therefore, count vectorizer allows me to determine the total number of occurrences for each card and enemy. Health and floor values were already numerical values, so they did not need to be converted into vectors. To create the final feature vector, I concatenate the cards, enemies, and relics encodings with the floor and health values. The target value in this set is the average damage taken per combat. The final model is a multilayer perceptron that takes the players attributes (their relics, cards, health, enemies fought,etc.) and calculates the average damage they will incur in future fights.

# %% [markdown]
# **Step 1:**
# Import Data

# %%
import json
import numpy as np
import pandas as pd

with open("Spirelogs") as f:
    data = json.load(f)

# %%
data
# Out:
# [{'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Quick Slash'],
#   'relics': ['Ring of the Snake', 'NeowsBlessing'],
#   'max_hp': 66,
#   'entering_hp': 59,
#   'character': 'THE_SILENT',
#   'ascension': 17,
#   'enemies': 'Small Slimes',
#   'potion_used': False,
#   'floor': 4,
#   'damage_taken': 0},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Quick Slash',
#    'All Out Attack',
#    'Terror'],
#   'relics': ['Ring of the Snake', 'NeowsBlessing'],
#   'max_hp': 66,
#   'entering_hp': 59,
#   'character': 'THE_SILENT',
#   'ascension': 17,
#   'enemies': 'Gremlin Nob',
#   'potion_used': False,
#   'floor': 6,
#   'damage_taken': 0},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Quick Slash',
#    'All Out Attack+1',
#    'Terror',
#    'Underhanded Strike'],
#   'relics': ['Ring of the Snake', 'NeowsBlessing', 'Dream Catcher'],
#   'max_hp': 66,
#   'entering_hp': 59,
#   'character': 'THE_SILENT',
#   'ascension': 17,
#   'enemies': 'Lagavulin',
#   'potion_used': False,
#   'floor': 8,
#   'damage_taken': 27},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Quick Slash+1',
#    'All Out Attack+1',
#    'Terror',
#    'Underhanded Strike+1',
#    'Dagger Throw+1'],
#   'relics': ['Ring of the Snake',
#    'NeowsBlessing',
#    'Dream Catcher',
#    'Tingsha',
#    'Paper Crane'],
#   'max_hp': 66,
#   'entering_hp': 32,
#   'character': 'THE_SILENT',
#   'ascension': 17,
#   'enemies': 'Jaw Worm',
#   'potion_used': False,
#   'floor': 13,
#   'damage_taken': 0},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize+1',
#    'AscendersBane',
#    'Quick Slash+1',
#    'All Out Attack+1',
#    'Terror',
#    'Underhanded Strike+1',
#    'Dagger Throw+1',
#    'Well Laid Plans'],
#   'relics': ['Ring of the Snake',
#    'NeowsBlessing',
#    'Dream Catcher',
#    'Tingsha',
#    'Paper Crane'],
#   'max_hp': 66,
#   'entering_hp': 32,
#   'character': 'THE_SILENT',
#   'ascension': 17,
#   'enemies': 'Slime Boss',
#   'potion_used': False,
#   'floor': 16,
#   'damage_taken': 32},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Deadly Poison'],
#   'relics': ['Ring of the Snake'],
#   'max_hp': 72,
#   'entering_hp': 63,
#   'character': 'THE_SILENT',
#   'ascension': 17,
#   'enemies': 'Jaw Worm',
#   'potion_used': False,
#   'floor': 2,
#   'damage_taken': 0},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Deadly Poison',
#    'Setup'],
#   'relics': ['Ring of the Snake'],
#   'max_hp': 72,
#   'entering_hp': 63,
#   'character': 'THE_SILENT',
#   'ascension': 17,
#   'enemies': 'Cultist',
#   'potion_used': False,
#   'floor': 3,
#   'damage_taken': 2},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Deadly Poison',
#    'Setup',
#    'Poisoned Stab'],
#   'relics': ['Ring of the Snake'],
#   'max_hp': 72,
#   'entering_hp': 61,
#   'character': 'THE_SILENT',
#   'ascension': 17,
#   'enemies': '3 Louse',
#   'potion_used': False,
#   'floor': 5,
#   'damage_taken': 10},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Deadly Poison',
#    'Setup+1',
#    'Poisoned Stab',
#    'Backflip',
#    'Poisoned Stab'],
#   'relics': ['Ring of the Snake'],
#   'max_hp': 72,
#   'entering_hp': 51,
#   'character': 'THE_SILENT',
#   'ascension': 17,
#   'enemies': '3 Sentries',
#   'potion_used': True,
#   'floor': 8,
#   'damage_taken': 14},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Deadly Poison',
#    'Setup+1',
#    'Poisoned Stab+1',
#    'Backflip',
#    'Poisoned Stab',
#    'Bullet Time'],
#   'relics': ['Ring of the Snake', 'Meat on the Bone', 'The Courier'],
#   'max_hp': 72,
#   'entering_hp': 37,
#   'character': 'THE_SILENT',
#   'ascension': 17,
#   'enemies': 'Red Slaver',
#   'potion_used': False,
#   'floor': 11,
#   'damage_taken': 0},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Deadly Poison',
#    'Setup+1',
#    'Poisoned Stab+1',
#    'Backflip',
#    'Poisoned Stab',
#    'Bullet Time'],
#   'relics': ['Ring of the Snake', 'Meat on the Bone', 'The Courier'],
#   'max_hp': 72,
#   'entering_hp': 37,
#   'character': 'THE_SILENT',
#   'ascension': 17,
#   'enemies': 'Exordium Wildlife',
#   'potion_used': False,
#   'floor': 12,
#   'damage_taken': -4},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Deadly Poison',
#    'Setup+1',
#    'Poisoned Stab+1',
#    'Backflip',
#    'Poisoned Stab',
#    'Bullet Time',
#    'Terror'],
#   'relics': ['Ring of the Snake', 'Meat on the Bone', 'The Courier'],
#   'max_hp': 72,
#   'entering_hp': 41,
#   'character': 'THE_SILENT',
#   'ascension': 17,
#   'enemies': 'Lagavulin',
#   'potion_used': True,
#   'floor': 13,
#   'damage_taken': 6},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Deadly Poison',
#    'Setup+1',
#    'Poisoned Stab+1',
#    'Backflip',
#    'Poisoned Stab',
#    'Bullet Time',
#    'Terror',
#    'Catalyst+1',
#    'Regret'],
#   'relics': ['Ring of the Snake',
#    'Meat on the Bone',
#    'The Courier',
#    'Juzu Bracelet',
#    'Pantograph'],
#   'max_hp': 72,
#   'entering_hp': 35,
#   'character': 'THE_SILENT',
#   'ascension': 17,
#   'enemies': 'Slime Boss',
#   'potion_used': True,
#   'floor': 16,
#   'damage_taken': 35},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Outmaneuver',
#    'Grand Finale'],
#   'relics': ['Ring of the Snake', 'NeowsBlessing'],
#   'max_hp': 66,
#   'entering_hp': 59,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': 'Jaw Worm',
#   'potion_used': False,
#   'floor': 3,
#   'damage_taken': 0},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Outmaneuver',
#    'Grand Finale',
#    'Predator'],
#   'relics': ['Ring of the Snake', 'NeowsBlessing'],
#   'max_hp': 66,
#   'entering_hp': 59,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': 'Gremlin Nob',
#   'potion_used': False,
#   'floor': 6,
#   'damage_taken': -7},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Outmaneuver',
#    'Grand Finale',
#    'Predator',
#    'Leg Sweep'],
#   'relics': ['Ring of the Snake', 'NeowsBlessing', 'Strawberry'],
#   'max_hp': 73,
#   'entering_hp': 66,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': '2 Louse',
#   'potion_used': False,
#   'floor': 7,
#   'damage_taken': 3},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Outmaneuver+1',
#    'Grand Finale',
#    'Predator+1',
#    'Leg Sweep',
#    'Escape Plan'],
#   'relics': ['Ring of the Snake',
#    'NeowsBlessing',
#    'Strawberry',
#    'Happy Flower'],
#   'max_hp': 73,
#   'entering_hp': 63,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': 'Lagavulin',
#   'potion_used': False,
#   'floor': 11,
#   'damage_taken': 11},
#  {'cards': ['Strike_G+1',
#    'Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G+1',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Outmaneuver+1',
#    'Grand Finale',
#    'Predator+1',
#    'Leg Sweep',
#    'Escape Plan',
#    'Well Laid Plans+1'],
#   'relics': ['Ring of the Snake',
#    'NeowsBlessing',
#    'Strawberry',
#    'Happy Flower',
#    'Boot',
#    'Letter Opener'],
#   'max_hp': 73,
#   'entering_hp': 30,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': 'Slime Boss',
#   'potion_used': False,
#   'floor': 16,
#   'damage_taken': 2},
#  {'cards': ['Strike_G+1',
#    'Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G+1',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Outmaneuver+1',
#    'Grand Finale',
#    'Predator+1',
#    'Leg Sweep',
#    'Escape Plan',
#    'Well Laid Plans+1'],
#   'relics': ['Ring of the Snake',
#    'NeowsBlessing',
#    'Strawberry',
#    'Happy Flower',
#    'Boot',
#    'Letter Opener',
#    'White Beast Statue'],
#   'max_hp': 73,
#   'entering_hp': 62,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': '3 Byrds',
#   'potion_used': False,
#   'floor': 18,
#   'damage_taken': 16},
#  {'cards': ['Strike_G+1',
#    'Strike_G',
#    'Defend_G+1',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Outmaneuver+1',
#    'Grand Finale',
#    'Predator+1',
#    'Leg Sweep',
#    'Escape Plan',
#    'Well Laid Plans+1',
#    'Backflip',
#    'Acrobatics'],
#   'relics': ['Ring of the Snake',
#    'NeowsBlessing',
#    'Strawberry',
#    'Happy Flower',
#    'Boot',
#    'Letter Opener',
#    'White Beast Statue'],
#   'max_hp': 73,
#   'entering_hp': 46,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': '2 Thieves',
#   'potion_used': False,
#   'floor': 22,
#   'damage_taken': 0},
#  {'cards': ['Strike_G+1',
#    'Strike_G',
#    'Defend_G+1',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Outmaneuver+1',
#    'Grand Finale',
#    'Predator+1',
#    'Leg Sweep',
#    'Escape Plan',
#    'Well Laid Plans+1',
#    'Backflip',
#    'Acrobatics+1'],
#   'relics': ['Ring of the Snake',
#    'NeowsBlessing',
#    'Strawberry',
#    'Happy Flower',
#    'Boot',
#    'Letter Opener',
#    'White Beast Statue'],
#   'max_hp': 73,
#   'entering_hp': 46,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': 'Centurion and Healer',
#   'potion_used': False,
#   'floor': 24,
#   'damage_taken': 0},
#  {'cards': ['Strike_G+1',
#    'Strike_G',
#    'Defend_G+1',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Outmaneuver+1',
#    'Grand Finale+1',
#    'Predator+1',
#    'Leg Sweep',
#    'Escape Plan',
#    'Well Laid Plans+1',
#    'Backflip',
#    'Acrobatics+1'],
#   'relics': ['Ring of the Snake',
#    'NeowsBlessing',
#    'Strawberry',
#    'Happy Flower',
#    'Boot',
#    'Letter Opener',
#    'White Beast Statue',
#    'Question Card'],
#   'max_hp': 73,
#   'entering_hp': 46,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': 'Snake Plant',
#   'potion_used': False,
#   'floor': 27,
#   'damage_taken': 7},
#  {'cards': ['Strike_G+1',
#    'Strike_G',
#    'Defend_G+1',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Outmaneuver+1',
#    'Grand Finale+1',
#    'Predator+1',
#    'Leg Sweep',
#    'Escape Plan',
#    'Well Laid Plans+1',
#    'Backflip',
#    'Acrobatics+1',
#    'Night Terror'],
#   'relics': ['Ring of the Snake',
#    'NeowsBlessing',
#    'Strawberry',
#    'Happy Flower',
#    'Boot',
#    'Letter Opener',
#    'White Beast Statue',
#    'Question Card'],
#   'max_hp': 73,
#   'entering_hp': 39,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': 'Book of Stabbing',
#   'potion_used': False,
#   'floor': 28,
#   'damage_taken': 6},
#  {'cards': ['Strike_G+1',
#    'Strike_G',
#    'Defend_G+1',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Outmaneuver+1',
#    'Grand Finale+1',
#    'Predator+1',
#    'Leg Sweep',
#    'Escape Plan',
#    'Well Laid Plans+1',
#    'Backflip',
#    'Acrobatics+1',
#    'Night Terror'],
#   'relics': ['Ring of the Snake',
#    'NeowsBlessing',
#    'Strawberry',
#    'Happy Flower',
#    'Boot',
#    'Letter Opener',
#    'White Beast Statue',
#    'Question Card',
#    'Unceasing Top'],
#   'max_hp': 73,
#   'entering_hp': 33,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': 'Sentry and Sphere',
#   'potion_used': False,
#   'floor': 29,
#   'damage_taken': 0},
#  {'cards': ['Strike_G+1',
#    'Strike_G',
#    'Defend_G+1',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Outmaneuver+1',
#    'Grand Finale+1',
#    'Predator+1',
#    'Leg Sweep',
#    'Escape Plan',
#    'Well Laid Plans+1',
#    'Backflip',
#    'Acrobatics+1',
#    'Night Terror',
#    'Acrobatics',
#    'Grand Finale'],
#   'relics': ['Ring of the Snake',
#    'NeowsBlessing',
#    'Strawberry',
#    'Happy Flower',
#    'Boot',
#    'Letter Opener',
#    'White Beast Statue',
#    'Question Card',
#    'Unceasing Top'],
#   'max_hp': 73,
#   'entering_hp': 33,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': 'Centurion and Healer',
#   'potion_used': False,
#   'floor': 31,
#   'damage_taken': 3},
#  {'cards': ['Strike_G+1',
#    'Strike_G',
#    'Defend_G+1',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Outmaneuver+1',
#    'Grand Finale+1',
#    'Predator+1',
#    'Leg Sweep',
#    'Escape Plan',
#    'Well Laid Plans+1',
#    'Backflip',
#    'Acrobatics+1',
#    'Night Terror+1',
#    'Acrobatics',
#    'Grand Finale',
#    'Footwork+1'],
#   'relics': ['Ring of the Snake',
#    'NeowsBlessing',
#    'Strawberry',
#    'Happy Flower',
#    'Boot',
#    'Letter Opener',
#    'White Beast Statue',
#    'Question Card',
#    'Unceasing Top'],
#   'max_hp': 73,
#   'entering_hp': 30,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': 'Collector',
#   'potion_used': True,
#   'floor': 33,
#   'damage_taken': 29},
#  {'cards': ['Strike_G+1',
#    'Strike_G',
#    'Defend_G+1',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Outmaneuver+1',
#    'Grand Finale+1',
#    'Predator+1',
#    'Leg Sweep',
#    'Escape Plan',
#    'Well Laid Plans+1',
#    'Backflip',
#    'Acrobatics+1',
#    'Night Terror+1',
#    'Acrobatics',
#    'Grand Finale',
#    'Footwork+1',
#    'Burst'],
#   'relics': ['Ring of the Snake',
#    'NeowsBlessing',
#    'Strawberry',
#    'Happy Flower',
#    'Boot',
#    'Letter Opener',
#    'White Beast Statue',
#    'Question Card',
#    'Unceasing Top',
#    'Eternal Feather'],
#   'max_hp': 73,
#   'entering_hp': 55,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': 'Orb Walker',
#   'potion_used': False,
#   'floor': 35,
#   'damage_taken': 4},
#  {'cards': ['Strike_G+1',
#    'Strike_G',
#    'Defend_G+1',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Outmaneuver+1',
#    'Grand Finale+1',
#    'Predator+1',
#    'Leg Sweep',
#    'Escape Plan',
#    'Well Laid Plans+1',
#    'Backflip',
#    'Acrobatics+1',
#    'Night Terror+1',
#    'Acrobatics',
#    'Grand Finale',
#    'Footwork+1',
#    'Burst',
#    'Dagger Throw+1'],
#   'relics': ['Ring of the Snake',
#    'NeowsBlessing',
#    'Strawberry',
#    'Happy Flower',
#    'Boot',
#    'Letter Opener',
#    'White Beast Statue',
#    'Question Card',
#    'Unceasing Top',
#    'Eternal Feather'],
#   'max_hp': 73,
#   'entering_hp': 51,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': 'Mind Bloom Boss Battle',
#   'potion_used': True,
#   'floor': 36,
#   'damage_taken': 0},
#  {'cards': ['Strike_G+1',
#    'Strike_G',
#    'Defend_G+1',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Outmaneuver+1',
#    'Grand Finale+1',
#    'Predator+1',
#    'Leg Sweep',
#    'Escape Plan',
#    'Well Laid Plans+1',
#    'Backflip',
#    'Acrobatics+1',
#    'Night Terror+1',
#    'Acrobatics',
#    'Grand Finale',
#    'Footwork+1',
#    'Burst',
#    'Dagger Throw+1',
#    'Backflip+1'],
#   'relics': ['Ring of the Snake',
#    'NeowsBlessing',
#    'Strawberry',
#    'Happy Flower',
#    'Boot',
#    'Letter Opener',
#    'White Beast Statue',
#    'Question Card',
#    'Unceasing Top',
#    'Eternal Feather',
#    'Shovel'],
#   'max_hp': 73,
#   'entering_hp': 51,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': '3 Shapes',
#   'potion_used': False,
#   'floor': 37,
#   'damage_taken': 9},
#  {'cards': ['Strike_G+1',
#    'Strike_G',
#    'Defend_G+1',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Outmaneuver+1',
#    'Grand Finale+1',
#    'Predator+1',
#    'Leg Sweep',
#    'Escape Plan',
#    'Well Laid Plans+1',
#    'Backflip',
#    'Acrobatics+1',
#    'Night Terror+1',
#    'Acrobatics',
#    'Grand Finale',
#    'Footwork+1',
#    'Burst+1',
#    'Dagger Throw+1',
#    'Backflip+1'],
#   'relics': ['Ring of the Snake',
#    'NeowsBlessing',
#    'Strawberry',
#    'Happy Flower',
#    'Boot',
#    'Letter Opener',
#    'White Beast Statue',
#    'Question Card',
#    'Unceasing Top',
#    'Eternal Feather',
#    'Shovel'],
#   'max_hp': 73,
#   'entering_hp': 42,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': 'Sphere and 2 Shapes',
#   'potion_used': False,
#   'floor': 39,
#   'damage_taken': 1},
#  {'cards': ['Strike_G+1',
#    'Strike_G',
#    'Defend_G+1',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Outmaneuver+1',
#    'Grand Finale+1',
#    'Predator+1',
#    'Leg Sweep',
#    'Escape Plan',
#    'Well Laid Plans+1',
#    'Backflip',
#    'Acrobatics+1',
#    'Night Terror+1',
#    'Acrobatics',
#    'Grand Finale',
#    'Footwork+1',
#    'Burst+1',
#    'Dagger Throw+1',
#    'Backflip+1',
#    'Tactician+1'],
#   'relics': ['Ring of the Snake',
#    'NeowsBlessing',
#    'Strawberry',
#    'Happy Flower',
#    'Boot',
#    'Letter Opener',
#    'White Beast Statue',
#    'Question Card',
#    'Unceasing Top',
#    'Eternal Feather',
#    'Shovel'],
#   'max_hp': 73,
#   'entering_hp': 56,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': 'Nemesis',
#   'potion_used': False,
#   'floor': 41,
#   'damage_taken': 0},
#  {'cards': ['Strike_G+1',
#    'Strike_G',
#    'Defend_G+1',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Outmaneuver+1',
#    'Grand Finale+1',
#    'Predator+1',
#    'Leg Sweep',
#    'Escape Plan',
#    'Well Laid Plans+1',
#    'Backflip',
#    'Acrobatics+1',
#    'Night Terror+1',
#    'Acrobatics+1',
#    'Grand Finale+1',
#    'Footwork+1',
#    'Burst+1',
#    'Dagger Throw+1',
#    'Backflip+1',
#    'Tactician+1',
#    'Footwork+1'],
#   'relics': ['Ring of the Snake',
#    'NeowsBlessing',
#    'Strawberry',
#    'Happy Flower',
#    'Boot',
#    'Letter Opener',
#    'White Beast Statue',
#    'Question Card',
#    'Unceasing Top',
#    'Eternal Feather',
#    'Shovel',
#    'Gambling Chip',
#    'Centennial Puzzle'],
#   'max_hp': 73,
#   'entering_hp': 73,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': 'Writhing Mass',
#   'potion_used': True,
#   'floor': 45,
#   'damage_taken': 0},
#  {'cards': ['Strike_G+1',
#    'Defend_G+1',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Outmaneuver+1',
#    'Grand Finale+1',
#    'Predator+1',
#    'Leg Sweep',
#    'Escape Plan',
#    'Well Laid Plans+1',
#    'Backflip',
#    'Acrobatics+1',
#    'Night Terror+1',
#    'Acrobatics+1',
#    'Grand Finale+1',
#    'Footwork+1',
#    'Burst+1',
#    'Dagger Throw+1',
#    'Backflip+1',
#    'Tactician+1',
#    'Footwork+1',
#    'Prepared+1',
#    'Prepared'],
#   'relics': ['Ring of the Snake',
#    'NeowsBlessing',
#    'Strawberry',
#    'Happy Flower',
#    'Boot',
#    'Letter Opener',
#    'White Beast Statue',
#    'Question Card',
#    'Unceasing Top',
#    'Eternal Feather',
#    'Shovel',
#    'Gambling Chip',
#    'Centennial Puzzle',
#    'Bag of Marbles'],
#   'max_hp': 73,
#   'entering_hp': 73,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': 'Transient',
#   'potion_used': True,
#   'floor': 47,
#   'damage_taken': 0},
#  {'cards': ['Strike_G+1',
#    'Defend_G+1',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Outmaneuver+1',
#    'Grand Finale+1',
#    'Predator+1',
#    'Leg Sweep',
#    'Escape Plan',
#    'Well Laid Plans+1',
#    'Backflip',
#    'Acrobatics+1',
#    'Night Terror+1',
#    'Acrobatics+1',
#    'Grand Finale+1',
#    'Footwork+1',
#    'Burst+1',
#    'Dagger Throw+1',
#    'Backflip+1',
#    'Tactician+1',
#    'Footwork+1',
#    'Prepared+1',
#    'Prepared'],
#   'relics': ['Ring of the Snake',
#    'NeowsBlessing',
#    'Strawberry',
#    'Happy Flower',
#    'Boot',
#    'Letter Opener',
#    'White Beast Statue',
#    'Question Card',
#    'Unceasing Top',
#    'Eternal Feather',
#    'Shovel',
#    'Gambling Chip',
#    'Centennial Puzzle',
#    'Bag of Marbles',
#    'Bottled Lightning'],
#   'max_hp': 73,
#   'entering_hp': 73,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': 'Donu and Deca',
#   'potion_used': True,
#   'floor': 50,
#   'damage_taken': 29},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Leg Sweep'],
#   'relics': ['Ring of the Snake'],
#   'max_hp': 66,
#   'entering_hp': 55,
#   'character': 'THE_SILENT',
#   'ascension': 17,
#   'enemies': '2 Louse',
#   'potion_used': False,
#   'floor': 2,
#   'damage_taken': 3},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G+1',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Leg Sweep+1',
#    'Riddle With Holes'],
#   'relics': ['Ring of the Snake'],
#   'max_hp': 66,
#   'entering_hp': 46,
#   'character': 'THE_SILENT',
#   'ascension': 17,
#   'enemies': '3 Sentries',
#   'potion_used': False,
#   'floor': 6,
#   'damage_taken': 32},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G+1',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Leg Sweep+1',
#    'Riddle With Holes',
#    'Corpse Explosion'],
#   'relics': ['Ring of the Snake', 'Art of War', 'The Specimen'],
#   'max_hp': 66,
#   'entering_hp': 55,
#   'character': 'THE_SILENT',
#   'ascension': 17,
#   'enemies': 'Cultist',
#   'potion_used': False,
#   'floor': 10,
#   'damage_taken': 0},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G+1',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Leg Sweep+1',
#    'Riddle With Holes',
#    'Corpse Explosion',
#    'Calculated Gamble'],
#   'relics': ['Ring of the Snake', 'Art of War', 'The Specimen'],
#   'max_hp': 66,
#   'entering_hp': 55,
#   'character': 'THE_SILENT',
#   'ascension': 17,
#   'enemies': 'Lagavulin',
#   'potion_used': False,
#   'floor': 11,
#   'damage_taken': 16},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G+1',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Leg Sweep+1',
#    'Riddle With Holes',
#    'Corpse Explosion',
#    'Calculated Gamble',
#    'Catalyst'],
#   'relics': ['Ring of the Snake', 'Art of War', 'The Specimen', 'Ginger'],
#   'max_hp': 66,
#   'entering_hp': 39,
#   'character': 'THE_SILENT',
#   'ascension': 17,
#   'enemies': 'Exordium Thugs',
#   'potion_used': False,
#   'floor': 12,
#   'damage_taken': 6},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G+1',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Leg Sweep+1',
#    'Riddle With Holes',
#    'Corpse Explosion',
#    'Calculated Gamble',
#    'Catalyst',
#    'Doppelganger'],
#   'relics': ['Ring of the Snake', 'Art of War', 'The Specimen', 'Ginger'],
#   'max_hp': 66,
#   'entering_hp': 33,
#   'character': 'THE_SILENT',
#   'ascension': 17,
#   'enemies': '3 Sentries',
#   'potion_used': False,
#   'floor': 13,
#   'damage_taken': 20},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G+1',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Leg Sweep+1',
#    'Riddle With Holes',
#    'Corpse Explosion',
#    'Calculated Gamble',
#    'Catalyst',
#    'Doppelganger',
#    'Deadly Poison'],
#   'relics': ['Ring of the Snake',
#    'Art of War',
#    'The Specimen',
#    'Ginger',
#    'Bird Faced Urn'],
#   'max_hp': 66,
#   'entering_hp': 13,
#   'character': 'THE_SILENT',
#   'ascension': 17,
#   'enemies': 'Exordium Wildlife',
#   'potion_used': False,
#   'floor': 14,
#   'damage_taken': 0},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G+1',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Leg Sweep+1',
#    'Riddle With Holes',
#    'Corpse Explosion',
#    'Calculated Gamble',
#    'Catalyst',
#    'Doppelganger',
#    'Deadly Poison',
#    'Backflip'],
#   'relics': ['Ring of the Snake',
#    'Art of War',
#    'The Specimen',
#    'Ginger',
#    'Bird Faced Urn'],
#   'max_hp': 66,
#   'entering_hp': 32,
#   'character': 'THE_SILENT',
#   'ascension': 17,
#   'enemies': 'Slime Boss',
#   'potion_used': True,
#   'floor': 16,
#   'damage_taken': 32},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Bane'],
#   'relics': ['Ring of the Snake', 'Smiling Mask'],
#   'max_hp': 66,
#   'entering_hp': 55,
#   'character': 'THE_SILENT',
#   'ascension': 17,
#   'enemies': 'Cultist',
#   'potion_used': False,
#   'floor': 2,
#   'damage_taken': 1},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Bane',
#    'All Out Attack',
#    'Leg Sweep'],
#   'relics': ['Ring of the Snake', 'Smiling Mask', 'Paper Crane'],
#   'max_hp': 66,
#   'entering_hp': 54,
#   'character': 'THE_SILENT',
#   'ascension': 17,
#   'enemies': '2 Louse',
#   'potion_used': False,
#   'floor': 5,
#   'damage_taken': 0},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Bane',
#    'All Out Attack',
#    'Leg Sweep',
#    'Quick Slash'],
#   'relics': ['Ring of the Snake', 'Smiling Mask', 'Paper Crane'],
#   'max_hp': 66,
#   'entering_hp': 54,
#   'character': 'THE_SILENT',
#   'ascension': 17,
#   'enemies': 'Lagavulin',
#   'potion_used': False,
#   'floor': 6,
#   'damage_taken': 44},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Bane',
#    'All Out Attack',
#    'Leg Sweep',
#    'Quick Slash',
#    'Terror'],
#   'relics': ['Ring of the Snake', 'Smiling Mask', 'Paper Crane', 'Turnip'],
#   'max_hp': 66,
#   'entering_hp': 29,
#   'character': 'THE_SILENT',
#   'ascension': 17,
#   'enemies': 'Gremlin Gang',
#   'potion_used': False,
#   'floor': 8,
#   'damage_taken': 0},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Bane',
#    'All Out Attack',
#    'Leg Sweep',
#    'Quick Slash',
#    'Terror',
#    'Sucker Punch'],
#   'relics': ['Ring of the Snake',
#    'Smiling Mask',
#    'Paper Crane',
#    'Turnip',
#    'Torii'],
#   'max_hp': 66,
#   'entering_hp': 29,
#   'character': 'THE_SILENT',
#   'ascension': 17,
#   'enemies': 'Lots of Slimes',
#   'potion_used': False,
#   'floor': 10,
#   'damage_taken': 3},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Bane',
#    'All Out Attack',
#    'Leg Sweep',
#    'Quick Slash',
#    'Terror',
#    'Sucker Punch',
#    'Riddle With Holes'],
#   'relics': ['Ring of the Snake',
#    'Smiling Mask',
#    'Paper Crane',
#    'Turnip',
#    'Torii'],
#   'max_hp': 66,
#   'entering_hp': 26,
#   'character': 'THE_SILENT',
#   'ascension': 17,
#   'enemies': '3 Louse',
#   'potion_used': False,
#   'floor': 11,
#   'damage_taken': 1},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Bane',
#    'All Out Attack',
#    'Leg Sweep',
#    'Quick Slash',
#    'Terror',
#    'Sucker Punch',
#    'Riddle With Holes',
#    'Envenom'],
#   'relics': ['Ring of the Snake',
#    'Smiling Mask',
#    'Paper Crane',
#    'Turnip',
#    'Torii'],
#   'max_hp': 66,
#   'entering_hp': 25,
#   'character': 'THE_SILENT',
#   'ascension': 17,
#   'enemies': 'Exordium Thugs',
#   'potion_used': False,
#   'floor': 12,
#   'damage_taken': 1},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Bane',
#    'All Out Attack',
#    'Leg Sweep',
#    'Quick Slash',
#    'Terror',
#    'Sucker Punch',
#    'Riddle With Holes',
#    'Envenom',
#    'Bouncing Flask'],
#   'relics': ['Ring of the Snake',
#    'Smiling Mask',
#    'Paper Crane',
#    'Turnip',
#    'Torii',
#    'Frozen Egg 2'],
#   'max_hp': 66,
#   'entering_hp': 24,
#   'character': 'THE_SILENT',
#   'ascension': 17,
#   'enemies': 'Gremlin Nob',
#   'potion_used': False,
#   'floor': 14,
#   'damage_taken': 17},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Bane',
#    'All Out Attack',
#    'Leg Sweep',
#    'Quick Slash',
#    'Terror',
#    'Sucker Punch',
#    'Riddle With Holes',
#    'Envenom',
#    'Bouncing Flask',
#    'Flechettes'],
#   'relics': ['Ring of the Snake',
#    'Smiling Mask',
#    'Paper Crane',
#    'Turnip',
#    'Torii',
#    'Frozen Egg 2',
#    'Bottled Tornado'],
#   'max_hp': 66,
#   'entering_hp': 26,
#   'character': 'THE_SILENT',
#   'ascension': 17,
#   'enemies': 'Slime Boss',
#   'potion_used': False,
#   'floor': 16,
#   'damage_taken': 26},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Poisoned Stab',
#    'Wraith Form v2'],
#   'relics': ['Ring of the Snake', 'NeowsBlessing'],
#   'max_hp': 66,
#   'entering_hp': 48,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': '3 Sentries',
#   'potion_used': False,
#   'floor': 6,
#   'damage_taken': 0},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Poisoned Stab',
#    'Wraith Form v2',
#    'Die Die Die'],
#   'relics': ['Ring of the Snake', 'NeowsBlessing', 'Happy Flower'],
#   'max_hp': 66,
#   'entering_hp': 48,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': 'Small Slimes',
#   'potion_used': False,
#   'floor': 7,
#   'damage_taken': 0},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Poisoned Stab',
#    'Wraith Form v2',
#    'Die Die Die',
#    'Deadly Poison'],
#   'relics': ['Ring of the Snake', 'NeowsBlessing', 'Happy Flower'],
#   'max_hp': 66,
#   'entering_hp': 48,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': '2 Louse',
#   'potion_used': False,
#   'floor': 8,
#   'damage_taken': 0},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Poisoned Stab',
#    'Wraith Form v2',
#    'Die Die Die',
#    'Deadly Poison',
#    'Poisoned Stab'],
#   'relics': ['Ring of the Snake',
#    'NeowsBlessing',
#    'Happy Flower',
#    'Orichalcum'],
#   'max_hp': 66,
#   'entering_hp': 48,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': 'Gremlin Nob',
#   'potion_used': True,
#   'floor': 10,
#   'damage_taken': 26},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Poisoned Stab',
#    'Wraith Form v2',
#    'Die Die Die',
#    'Deadly Poison',
#    'Poisoned Stab',
#    'Catalyst+1'],
#   'relics': ['Ring of the Snake',
#    'NeowsBlessing',
#    'Happy Flower',
#    'Orichalcum',
#    'Peace Pipe'],
#   'max_hp': 66,
#   'entering_hp': 22,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': 'Large Slime',
#   'potion_used': False,
#   'floor': 12,
#   'damage_taken': 10},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Poisoned Stab',
#    'Wraith Form v2',
#    'Die Die Die',
#    'Deadly Poison',
#    'Poisoned Stab',
#    'Catalyst+1',
#    'Phantasmal Killer'],
#   'relics': ['Ring of the Snake',
#    'NeowsBlessing',
#    'Happy Flower',
#    'Orichalcum',
#    'Peace Pipe'],
#   'max_hp': 66,
#   'entering_hp': 12,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': '3 Sentries',
#   'potion_used': True,
#   'floor': 13,
#   'damage_taken': 6},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Poisoned Stab',
#    'Wraith Form v2',
#    'Die Die Die',
#    'Deadly Poison',
#    'Poisoned Stab',
#    'Catalyst+1',
#    'Phantasmal Killer',
#    'Dodge and Roll'],
#   'relics': ['Ring of the Snake',
#    'NeowsBlessing',
#    'Happy Flower',
#    'Orichalcum',
#    'Peace Pipe',
#    'MawBank'],
#   'max_hp': 66,
#   'entering_hp': 6,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': 'Blue Slaver',
#   'potion_used': True,
#   'floor': 14,
#   'damage_taken': 0},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Poisoned Stab',
#    'Wraith Form v2',
#    'Die Die Die',
#    'Deadly Poison',
#    'Poisoned Stab',
#    'Catalyst+1',
#    'Phantasmal Killer',
#    'Dodge and Roll',
#    'Dash'],
#   'relics': ['Ring of the Snake',
#    'NeowsBlessing',
#    'Happy Flower',
#    'Orichalcum',
#    'Peace Pipe',
#    'MawBank'],
#   'max_hp': 66,
#   'entering_hp': 25,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': 'Hexaghost',
#   'potion_used': False,
#   'floor': 16,
#   'damage_taken': 25},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize+1',
#    'AscendersBane',
#    'Deadly Poison'],
#   'relics': ['Ring of the Snake', 'Darkstone Periapt'],
#   'max_hp': 66,
#   'entering_hp': 51,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': 'Cultist',
#   'potion_used': False,
#   'floor': 4,
#   'damage_taken': 0},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize+1',
#    'AscendersBane',
#    'Deadly Poison',
#    'Poisoned Stab'],
#   'relics': ['Ring of the Snake', 'Darkstone Periapt'],
#   'max_hp': 66,
#   'entering_hp': 51,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': 'Small Slimes',
#   'potion_used': False,
#   'floor': 5,
#   'damage_taken': 0},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize+1',
#    'AscendersBane',
#    'Deadly Poison',
#    'Poisoned Stab',
#    'Poisoned Stab'],
#   'relics': ['Ring of the Snake', 'Darkstone Periapt'],
#   'max_hp': 66,
#   'entering_hp': 51,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': 'Lagavulin',
#   'potion_used': True,
#   'floor': 6,
#   'damage_taken': 17},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize+1',
#    'AscendersBane',
#    'Deadly Poison',
#    'Poisoned Stab',
#    'Poisoned Stab',
#    'Leg Sweep'],
#   'relics': ['Ring of the Snake', 'Darkstone Periapt', 'Bag of Preparation'],
#   'max_hp': 66,
#   'entering_hp': 53,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': '3 Sentries',
#   'potion_used': True,
#   'floor': 8,
#   'damage_taken': 21},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize+1',
#    'AscendersBane',
#    'Deadly Poison+1',
#    'Poisoned Stab',
#    'Poisoned Stab',
#    'Leg Sweep',
#    'Corpse Explosion'],
#   'relics': ['Ring of the Snake',
#    'Darkstone Periapt',
#    'Bag of Preparation',
#    'Smiling Mask',
#    'Frozen Egg 2'],
#   'max_hp': 66,
#   'entering_hp': 32,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': 'Exordium Thugs',
#   'potion_used': True,
#   'floor': 11,
#   'damage_taken': 0},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize+1',
#    'AscendersBane',
#    'Deadly Poison+1',
#    'Poisoned Stab',
#    'Poisoned Stab',
#    'Leg Sweep',
#    'Corpse Explosion',
#    'Deadly Poison'],
#   'relics': ['Ring of the Snake',
#    'Darkstone Periapt',
#    'Bag of Preparation',
#    'Smiling Mask',
#    'Frozen Egg 2'],
#   'max_hp': 66,
#   'entering_hp': 32,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': 'Large Slime',
#   'potion_used': False,
#   'floor': 12,
#   'damage_taken': 19},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize+1',
#    'AscendersBane',
#    'Deadly Poison+1',
#    'Poisoned Stab',
#    'Poisoned Stab',
#    'Leg Sweep',
#    'Corpse Explosion',
#    'Deadly Poison'],
#   'relics': ['Ring of the Snake',
#    'Darkstone Periapt',
#    'Bag of Preparation',
#    'Smiling Mask',
#    'Frozen Egg 2'],
#   'max_hp': 66,
#   'entering_hp': 13,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': 'Exordium Wildlife',
#   'potion_used': False,
#   'floor': 13,
#   'damage_taken': 11},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize+1',
#    'AscendersBane',
#    'Deadly Poison+1',
#    'Poisoned Stab',
#    'Poisoned Stab',
#    'Leg Sweep',
#    'Corpse Explosion',
#    'Deadly Poison',
#    'Parasite'],
#   'relics': ['Ring of the Snake',
#    'Darkstone Periapt',
#    'Bag of Preparation',
#    'Smiling Mask',
#    'Frozen Egg 2'],
#   'max_hp': 72,
#   'entering_hp': 45,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': 'The Guardian',
#   'potion_used': True,
#   'floor': 16,
#   'damage_taken': 28},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize+1',
#    'AscendersBane',
#    'Deadly Poison+1',
#    'Poisoned Stab',
#    'Poisoned Stab',
#    'Leg Sweep',
#    'Corpse Explosion',
#    'Deadly Poison',
#    'Parasite',
#    'Burst'],
#   'relics': ['Ring of the Snake',
#    'Darkstone Periapt',
#    'Bag of Preparation',
#    'Smiling Mask',
#    'Frozen Egg 2',
#    'Busted Crown'],
#   'max_hp': 72,
#   'entering_hp': 58,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': '3 Byrds',
#   'potion_used': True,
#   'floor': 18,
#   'damage_taken': 0},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize+1',
#    'AscendersBane',
#    'Deadly Poison+1',
#    'Poisoned Stab',
#    'Poisoned Stab',
#    'Leg Sweep',
#    'Corpse Explosion',
#    'Deadly Poison',
#    'Parasite',
#    'Burst',
#    'Night Terror'],
#   'relics': ['Ring of the Snake',
#    'Darkstone Periapt',
#    'Bag of Preparation',
#    'Smiling Mask',
#    'Frozen Egg 2',
#    'Busted Crown'],
#   'max_hp': 72,
#   'entering_hp': 58,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': 'Shell Parasite',
#   'potion_used': False,
#   'floor': 20,
#   'damage_taken': 4},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize+1',
#    'AscendersBane',
#    'Deadly Poison+1',
#    'Poisoned Stab',
#    'Poisoned Stab',
#    'Leg Sweep',
#    'Corpse Explosion',
#    'Deadly Poison',
#    'Parasite',
#    'Burst',
#    'Night Terror',
#    'Well Laid Plans+1'],
#   'relics': ['Ring of the Snake',
#    'Darkstone Periapt',
#    'Bag of Preparation',
#    'Smiling Mask',
#    'Frozen Egg 2',
#    'Busted Crown'],
#   'max_hp': 72,
#   'entering_hp': 54,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': 'Centurion and Healer',
#   'potion_used': False,
#   'floor': 21,
#   'damage_taken': 1},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize+1',
#    'AscendersBane',
#    'Deadly Poison+1',
#    'Poisoned Stab',
#    'Poisoned Stab',
#    'Leg Sweep',
#    'Corpse Explosion',
#    'Deadly Poison',
#    'Parasite',
#    'Burst',
#    'Night Terror',
#    'Well Laid Plans+1'],
#   'relics': ['Ring of the Snake',
#    'Darkstone Periapt',
#    'Bag of Preparation',
#    'Smiling Mask',
#    'Frozen Egg 2',
#    'Busted Crown'],
#   'max_hp': 72,
#   'entering_hp': 53,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': 'Snecko',
#   'potion_used': False,
#   'floor': 22,
#   'damage_taken': 11},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize+1',
#    'AscendersBane',
#    'Deadly Poison+1',
#    'Poisoned Stab',
#    'Poisoned Stab',
#    'Leg Sweep',
#    'Corpse Explosion',
#    'Deadly Poison',
#    'Parasite',
#    'Burst+1',
#    'Night Terror',
#    'Well Laid Plans+1'],
#   'relics': ['Ring of the Snake',
#    'Darkstone Periapt',
#    'Bag of Preparation',
#    'Smiling Mask',
#    'Frozen Egg 2',
#    'Busted Crown'],
#   'max_hp': 72,
#   'entering_hp': 42,
#   'character': 'THE_SILENT',
#   'ascension': 16,
#   'enemies': 'Book of Stabbing',
#   'potion_used': False,
#   'floor': 24,
#   'damage_taken': 42},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Flechettes'],
#   'relics': ['Ring of the Snake', 'Smiling Mask'],
#   'max_hp': 66,
#   'entering_hp': 54,
#   'character': 'THE_SILENT',
#   'ascension': 15,
#   'enemies': '2 Louse',
#   'potion_used': False,
#   'floor': 3,
#   'damage_taken': 0},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Flechettes',
#    'Flechettes'],
#   'relics': ['Ring of the Snake', 'Smiling Mask'],
#   'max_hp': 66,
#   'entering_hp': 54,
#   'character': 'THE_SILENT',
#   'ascension': 15,
#   'enemies': 'Small Slimes',
#   'potion_used': False,
#   'floor': 4,
#   'damage_taken': 4},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Flechettes',
#    'Flechettes',
#    'Setup'],
#   'relics': ['Ring of the Snake', 'Smiling Mask'],
#   'max_hp': 66,
#   'entering_hp': 50,
#   'character': 'THE_SILENT',
#   'ascension': 15,
#   'enemies': 'Exordium Wildlife',
#   'potion_used': False,
#   'floor': 5,
#   'damage_taken': 1},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Flechettes+1',
#    'Flechettes',
#    'Setup'],
#   'relics': ['Ring of the Snake', 'Smiling Mask'],
#   'max_hp': 66,
#   'entering_hp': 49,
#   'character': 'THE_SILENT',
#   'ascension': 15,
#   'enemies': 'Large Slime',
#   'potion_used': False,
#   'floor': 7,
#   'damage_taken': 18},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Flechettes+1',
#    'Flechettes',
#    'Setup',
#    'Cloak And Dagger'],
#   'relics': ['Ring of the Snake', 'Smiling Mask'],
#   'max_hp': 66,
#   'entering_hp': 31,
#   'character': 'THE_SILENT',
#   'ascension': 15,
#   'enemies': 'Looter',
#   'potion_used': False,
#   'floor': 8,
#   'damage_taken': 0},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Flechettes+1',
#    'Flechettes',
#    'Setup',
#    'Cloak And Dagger',
#    'Flechettes'],
#   'relics': ['Ring of the Snake', 'Smiling Mask', 'Sundial'],
#   'max_hp': 66,
#   'entering_hp': 31,
#   'character': 'THE_SILENT',
#   'ascension': 15,
#   'enemies': 'Lagavulin',
#   'potion_used': False,
#   'floor': 10,
#   'damage_taken': 31},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Footwork',
#    'Cloak And Dagger+1',
#    'Footwork'],
#   'relics': ['Ring of the Snake', 'NeowsBlessing'],
#   'max_hp': 66,
#   'entering_hp': 66,
#   'character': 'THE_SILENT',
#   'ascension': 15,
#   'enemies': 'Lagavulin',
#   'potion_used': False,
#   'floor': 7,
#   'damage_taken': -5},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Footwork',
#    'Cloak And Dagger+1',
#    'Footwork',
#    'Tools of the Trade'],
#   'relics': ['Ring of the Snake', 'NeowsBlessing', 'Mummified Hand'],
#   'max_hp': 71,
#   'entering_hp': 71,
#   'character': 'THE_SILENT',
#   'ascension': 15,
#   'enemies': 'Small Slimes',
#   'potion_used': False,
#   'floor': 8,
#   'damage_taken': 0},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Footwork',
#    'Cloak And Dagger+1',
# ...
#   'character': 'THE_SILENT',
#   'ascension': 0,
#   'enemies': 'Cultist',
#   'potion_used': False,
#   'floor': 4,
#   'damage_taken': 1},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'Accuracy',
#    'Infinite Blades'],
#   'relics': ['Ring of the Snake'],
#   'max_hp': 77,
#   'entering_hp': 71,
#   'character': 'THE_SILENT',
#   'ascension': 0,
#   'enemies': 'Exordium Thugs',
#   'potion_used': True,
#   'floor': 6,
#   'damage_taken': 15},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'Accuracy+1',
#    'Infinite Blades+1'],
#   'relics': ['Ring of the Snake', 'Bronze Scales'],
#   'max_hp': 77,
#   'entering_hp': 56,
#   'character': 'THE_SILENT',
#   'ascension': 0,
#   'enemies': '2 Fungi Beasts',
#   'potion_used': False,
#   'floor': 11,
#   'damage_taken': 3},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'Accuracy+1',
#    'Infinite Blades+1',
#    'Cloak And Dagger'],
#   'relics': ['Ring of the Snake', 'Bronze Scales'],
#   'max_hp': 77,
#   'entering_hp': 53,
#   'character': 'THE_SILENT',
#   'ascension': 0,
#   'enemies': 'Blue Slaver',
#   'potion_used': False,
#   'floor': 12,
#   'damage_taken': 4},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'Accuracy+1',
#    'Infinite Blades+1',
#    'Cloak And Dagger',
#    'Predator'],
#   'relics': ['Ring of the Snake', 'Bronze Scales'],
#   'max_hp': 77,
#   'entering_hp': 49,
#   'character': 'THE_SILENT',
#   'ascension': 0,
#   'enemies': 'Red Slaver',
#   'potion_used': False,
#   'floor': 14,
#   'damage_taken': 8},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize+1',
#    'Accuracy+1',
#    'Infinite Blades+1',
#    'Cloak And Dagger',
#    'Predator',
#    'Blur'],
#   'relics': ['Ring of the Snake', 'Bronze Scales'],
#   'max_hp': 77,
#   'entering_hp': 41,
#   'character': 'THE_SILENT',
#   'ascension': 0,
#   'enemies': 'Hexaghost',
#   'potion_used': False,
#   'floor': 16,
#   'damage_taken': 30},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize+1',
#    'Accuracy+1',
#    'Infinite Blades+1',
#    'Cloak And Dagger',
#    'Predator',
#    'Blur',
#    'Burst'],
#   'relics': ['Ring of the Snake', 'Bronze Scales', "Philosopher's Stone"],
#   'max_hp': 77,
#   'entering_hp': 77,
#   'character': 'THE_SILENT',
#   'ascension': 0,
#   'enemies': 'Chosen',
#   'potion_used': False,
#   'floor': 18,
#   'damage_taken': 0},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize+1',
#    'Accuracy+1',
#    'Infinite Blades+1',
#    'Cloak And Dagger',
#    'Predator',
#    'Blur',
#    'Burst',
#    'Cloak And Dagger+1'],
#   'relics': ['Ring of the Snake', 'Bronze Scales', "Philosopher's Stone"],
#   'max_hp': 77,
#   'entering_hp': 77,
#   'character': 'THE_SILENT',
#   'ascension': 0,
#   'enemies': 'Shell Parasite',
#   'potion_used': False,
#   'floor': 19,
#   'damage_taken': 0},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize+1',
#    'Accuracy+1',
#    'Infinite Blades+1',
#    'Cloak And Dagger',
#    'Predator',
#    'Blur',
#    'Burst',
#    'Cloak And Dagger+1',
#    'Dagger Throw+1'],
#   'relics': ['Ring of the Snake', 'Bronze Scales', "Philosopher's Stone"],
#   'max_hp': 77,
#   'entering_hp': 77,
#   'character': 'THE_SILENT',
#   'ascension': 0,
#   'enemies': 'Snake Plant',
#   'potion_used': False,
#   'floor': 20,
#   'damage_taken': 10},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize+1',
#    'Accuracy+1',
#    'Infinite Blades+1',
#    'Cloak And Dagger',
#    'Predator',
#    'Blur',
#    'Burst',
#    'Cloak And Dagger+1',
#    'Dagger Throw+1',
#    'Sucker Punch'],
#   'relics': ['Ring of the Snake', 'Bronze Scales', "Philosopher's Stone"],
#   'max_hp': 77,
#   'entering_hp': 67,
#   'character': 'THE_SILENT',
#   'ascension': 0,
#   'enemies': '3 Cultists',
#   'potion_used': True,
#   'floor': 22,
#   'damage_taken': 0},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize+1',
#    'Accuracy+1',
#    'Infinite Blades+1',
#    'Cloak And Dagger',
#    'Predator',
#    'Blur',
#    'Burst+1',
#    'Cloak And Dagger+1',
#    'Dagger Throw+1',
#    'Sucker Punch',
#    'Leg Sweep'],
#   'relics': ['Ring of the Snake', 'Bronze Scales', "Philosopher's Stone"],
#   'max_hp': 77,
#   'entering_hp': 67,
#   'character': 'THE_SILENT',
#   'ascension': 0,
#   'enemies': 'Book of Stabbing',
#   'potion_used': True,
#   'floor': 24,
#   'damage_taken': 14},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize+1',
#    'Accuracy+1',
#    'Infinite Blades+1',
#    'Cloak And Dagger',
#    'Predator',
#    'Blur',
#    'Burst+1',
#    'Cloak And Dagger+1',
#    'Dagger Throw+1',
#    'Sucker Punch',
#    'Leg Sweep',
#    'Prepared'],
#   'relics': ['Ring of the Snake',
#    'Bronze Scales',
#    "Philosopher's Stone",
#    'Omamori'],
#   'max_hp': 77,
#   'entering_hp': 53,
#   'character': 'THE_SILENT',
#   'ascension': 0,
#   'enemies': 'Centurion and Healer',
#   'potion_used': False,
#   'floor': 25,
#   'damage_taken': 0},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize+1',
#    'Accuracy+1',
#    'Infinite Blades+1',
#    'Cloak And Dagger',
#    'Predator',
#    'Blur',
#    'Burst+1',
#    'Cloak And Dagger+1',
#    'Dagger Throw+1',
#    'Sucker Punch',
#    'Leg Sweep',
#    'Prepared',
#    'Terror'],
#   'relics': ['Ring of the Snake',
#    'Bronze Scales',
#    "Philosopher's Stone",
#    'Omamori',
#    'Bag of Preparation'],
#   'max_hp': 77,
#   'entering_hp': 53,
#   'character': 'THE_SILENT',
#   'ascension': 0,
#   'enemies': 'Snake Plant',
#   'potion_used': True,
#   'floor': 27,
#   'damage_taken': 12},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize+1',
#    'Accuracy+1',
#    'Infinite Blades+1',
#    'Cloak And Dagger',
#    'Predator',
#    'Blur',
#    'Burst+1',
#    'Cloak And Dagger+1',
#    'Dagger Throw+1',
#    'Sucker Punch',
#    'Leg Sweep',
#    'Prepared',
#    'Terror'],
#   'relics': ['Ring of the Snake',
#    'Bronze Scales',
#    "Philosopher's Stone",
#    'Omamori',
#    'Bag of Preparation'],
#   'max_hp': 77,
#   'entering_hp': 41,
#   'character': 'THE_SILENT',
#   'ascension': 0,
#   'enemies': 'Slavers',
#   'potion_used': True,
#   'floor': 28,
#   'damage_taken': 12},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize+1',
#    'Accuracy+1',
#    'Infinite Blades+1',
#    'Cloak And Dagger',
#    'Predator',
#    'Blur',
#    'Burst+1',
#    'Cloak And Dagger+1',
#    'Dagger Throw+1',
#    'Sucker Punch',
#    'Leg Sweep',
#    'Prepared',
#    'Terror',
#    'Calculated Gamble'],
#   'relics': ['Ring of the Snake',
#    'Bronze Scales',
#    "Philosopher's Stone",
#    'Omamori',
#    'Bag of Preparation',
#    'Vajra'],
#   'max_hp': 77,
#   'entering_hp': 29,
#   'character': 'THE_SILENT',
#   'ascension': 0,
#   'enemies': 'Cultist and Chosen',
#   'potion_used': False,
#   'floor': 29,
#   'damage_taken': 22},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize+1',
#    'Accuracy+1',
#    'Infinite Blades+1',
#    'Cloak And Dagger',
#    'Predator',
#    'Blur',
#    'Burst+1',
#    'Cloak And Dagger+1',
#    'Dagger Throw+1',
#    'Sucker Punch',
#    'Leg Sweep',
#    'Prepared',
#    'Terror',
#    'Calculated Gamble'],
#   'relics': ['Ring of the Snake',
#    'Bronze Scales',
#    "Philosopher's Stone",
#    'Omamori',
#    'Bag of Preparation',
#    'Vajra'],
#   'max_hp': 77,
#   'entering_hp': 7,
#   'character': 'THE_SILENT',
#   'ascension': 0,
#   'enemies': 'Shelled Parasite and Fungi',
#   'potion_used': True,
#   'floor': 30,
#   'damage_taken': 7},
#  {'cards': ['Strike_R',
#    'Strike_R',
#    'Strike_R',
#    'Defend_R',
#    'Defend_R',
#    'Defend_R',
#    'Defend_R',
#    'Strike_R',
#    'Bash',
#    'AscendersBane',
#    'Shockwave'],
#   'relics': ['Burning Blood'],
#   'max_hp': 75,
#   'entering_hp': 60,
#   'character': 'IRONCLAD',
#   'ascension': 19,
#   'enemies': 'Small Slimes',
#   'potion_used': False,
#   'floor': 3,
#   'damage_taken': 9},
#  {'cards': ['Strike_R',
#    'Strike_R',
#    'Strike_R',
#    'Defend_R',
#    'Defend_R',
#    'Defend_R',
#    'Defend_R',
#    'Strike_R',
#    'Bash',
#    'AscendersBane',
#    'Shockwave',
#    'Metallicize'],
#   'relics': ['Burning Blood'],
#   'max_hp': 75,
#   'entering_hp': 51,
#   'character': 'IRONCLAD',
#   'ascension': 19,
#   'enemies': 'Cultist',
#   'potion_used': False,
#   'floor': 5,
#   'damage_taken': -3},
#  {'cards': ['Strike_R',
#    'Strike_R',
#    'Strike_R',
#    'Defend_R',
#    'Defend_R',
#    'Defend_R',
#    'Defend_R',
#    'Strike_R',
#    'Bash',
#    'AscendersBane',
#    'Shockwave',
#    'Metallicize',
#    'Sword Boomerang'],
#   'relics': ['Burning Blood'],
#   'max_hp': 75,
#   'entering_hp': 54,
#   'character': 'IRONCLAD',
#   'ascension': 19,
#   'enemies': 'Gremlin Nob',
#   'potion_used': False,
#   'floor': 6,
#   'damage_taken': 33},
#  {'cards': ['Strike_R',
#    'Strike_R',
#    'Strike_R',
#    'Defend_R',
#    'Defend_R',
#    'Defend_R',
#    'Defend_R',
#    'Strike_R',
#    'Bash',
#    'AscendersBane',
#    'Shockwave',
#    'Metallicize',
#    'Sword Boomerang',
#    'Rampage'],
#   'relics': ['Burning Blood', 'Mummified Hand'],
#   'max_hp': 75,
#   'entering_hp': 43,
#   'character': 'IRONCLAD',
#   'ascension': 19,
#   'enemies': 'Looter',
#   'potion_used': False,
#   'floor': 8,
#   'damage_taken': -2},
#  {'cards': ['Strike_R',
#    'Strike_R',
#    'Strike_R',
#    'Defend_R',
#    'Defend_R',
#    'Defend_R',
#    'Defend_R',
#    'Strike_R',
#    'Bash',
#    'AscendersBane',
#    'Shockwave',
#    'Metallicize',
#    'Sword Boomerang',
#    'Rampage',
#    'Cleave'],
#   'relics': ['Burning Blood', 'Mummified Hand', 'Potion Belt'],
#   'max_hp': 75,
#   'entering_hp': 45,
#   'character': 'IRONCLAD',
#   'ascension': 19,
#   'enemies': 'Lagavulin Event',
#   'potion_used': True,
#   'floor': 10,
#   'damage_taken': 45},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize+1',
#    'AscendersBane',
#    'Noxious Fumes'],
#   'relics': ['Ring of the Snake'],
#   'max_hp': 66,
#   'entering_hp': 55,
#   'character': 'THE_SILENT',
#   'ascension': 18,
#   'enemies': '2 Louse',
#   'potion_used': False,
#   'floor': 3,
#   'damage_taken': 1},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize+1',
#    'AscendersBane',
#    'Noxious Fumes',
#    'All Out Attack'],
#   'relics': ['Ring of the Snake'],
#   'max_hp': 66,
#   'entering_hp': 54,
#   'character': 'THE_SILENT',
#   'ascension': 18,
#   'enemies': 'Jaw Worm',
#   'potion_used': False,
#   'floor': 4,
#   'damage_taken': 17},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor+1',
#    'Neutralize+1',
#    'AscendersBane',
#    'Noxious Fumes',
#    'All Out Attack',
#    'Crippling Poison+1'],
#   'relics': ['Ring of the Snake'],
#   'max_hp': 66,
#   'entering_hp': 36,
#   'character': 'THE_SILENT',
#   'ascension': 18,
#   'enemies': 'Gremlin Nob',
#   'potion_used': False,
#   'floor': 7,
#   'damage_taken': 36},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize',
#    'AscendersBane',
#    'Flying Knee',
#    'Dodge and Roll',
#    'Slice'],
#   'relics': ['Ring of the Snake'],
#   'max_hp': 72,
#   'entering_hp': 63,
#   'character': 'THE_SILENT',
#   'ascension': 18,
#   'enemies': 'Cultist',
#   'potion_used': False,
#   'floor': 4,
#   'damage_taken': 4},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize+1',
#    'AscendersBane',
#    'Flying Knee',
#    'Dodge and Roll',
#    'Slice',
#    'Blur'],
#   'relics': ['Ring of the Snake', 'Boot'],
#   'max_hp': 72,
#   'entering_hp': 41,
#   'character': 'THE_SILENT',
#   'ascension': 18,
#   'enemies': '2 Louse',
#   'potion_used': False,
#   'floor': 7,
#   'damage_taken': 0},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize+1',
#    'AscendersBane',
#    'Flying Knee',
#    'Dodge and Roll+1',
#    'Slice',
#    'Blur',
#    'Infinite Blades'],
#   'relics': ['Ring of the Snake', 'Boot', 'Dream Catcher'],
#   'max_hp': 72,
#   'entering_hp': 41,
#   'character': 'THE_SILENT',
#   'ascension': 18,
#   'enemies': '2 Fungi Beasts',
#   'potion_used': False,
#   'floor': 10,
#   'damage_taken': 0},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize+1',
#    'AscendersBane',
#    'Flying Knee',
#    'Dodge and Roll+1',
#    'Slice',
#    'Blur',
#    'Infinite Blades',
#    'Escape Plan'],
#   'relics': ['Ring of the Snake', 'Boot', 'Dream Catcher'],
#   'max_hp': 72,
#   'entering_hp': 41,
#   'character': 'THE_SILENT',
#   'ascension': 18,
#   'enemies': '3 Louse',
#   'potion_used': False,
#   'floor': 11,
#   'damage_taken': 2},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize+1',
#    'AscendersBane',
#    'Flying Knee',
#    'Dodge and Roll+1',
#    'Slice',
#    'Blur',
#    'Infinite Blades',
#    'Escape Plan',
#    'PiercingWail+1'],
#   'relics': ['Ring of the Snake', 'Boot', 'Dream Catcher'],
#   'max_hp': 72,
#   'entering_hp': 39,
#   'character': 'THE_SILENT',
#   'ascension': 18,
#   'enemies': 'Exordium Thugs',
#   'potion_used': False,
#   'floor': 13,
#   'damage_taken': 0},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize+1',
#    'AscendersBane',
#    'Flying Knee',
#    'Dodge and Roll+1',
#    'Slice',
#    'Blur',
#    'Infinite Blades',
#    'Escape Plan',
#    'PiercingWail+1',
#    'Skewer'],
#   'relics': ['Ring of the Snake', 'Boot', 'Dream Catcher'],
#   'max_hp': 72,
#   'entering_hp': 39,
#   'character': 'THE_SILENT',
#   'ascension': 18,
#   'enemies': 'Blue Slaver',
#   'potion_used': False,
#   'floor': 14,
#   'damage_taken': 0},
#  {'cards': ['Strike_G',
#    'Strike_G',
#    'Strike_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Defend_G',
#    'Strike_G',
#    'Defend_G',
#    'Survivor',
#    'Neutralize+1',
#    'AscendersBane',
#    'Flying Knee',
#    'Dodge and Roll+1',
#    'Slice',
#    'Blur',
#    'Infinite Blades',
#    'Escape Plan',
#    'PiercingWail+1',
#    'Skewer+1'],
#   'relics': ['Ring of the Snake', 'Boot', 'Dream Catcher'],
#   'max_hp': 72,
#   'entering_hp': 39,
#   'character': 'THE_SILENT',
#   'ascension': 18,
#   'enemies': 'Hexaghost',
#   'potion_used': True,
#   'floor': 16,
#   'damage_taken': 39},
#  ...]

# %% [markdown]
# **Step 2:** Filter out extraneous data and separate the data into each individual game

# %%
watcher_data_raw = [x for x in data if x["ascension"] == 20 if x["character"] == "WATCHER"]

# %%
for x in watcher_data_raw:
    for y in range(len(x["cards"])):
        x["cards"][y] = x["cards"][y].replace("+1","")

# %%
diff = np.diff([x["floor"] for x in watcher_data_raw])
split_arr = np.where(diff<0)[0]+1
watcher_data = np.split(watcher_data_raw,split_arr)

# %% [markdown]
# **Step 3:** Calculate the health loss per combat associated with each deck

# %%
for run in watcher_data:
    damage = []
    total_enemies = []
    for floor in run:
        damage.append(floor["damage_taken"])
    for floor in run:
        floor["entering_hp"] = floor["entering_hp"]-floor["damage_taken"]
        floor["enemies"] = floor["enemies"].replace(" ","")
        total_enemies.append(floor["enemies"])
        avg = np.average(damage)
        damage.pop(0)
        floor["damage_taken"] = avg
        floor["enemies"] = np.copy(total_enemies)

# %% [markdown]
# **Step 4:** Encode Categorical Features

# %%
watcher_data
# Out:
# [array([{'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'WheelKick'], 'relics': ['Snecko Eye'], 'max_hp': 68, 'entering_hp': 56, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Cultist', 'potion_used': False, 'floor': 2, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'WheelKick', 'Perseverance'], 'relics': ['Snecko Eye'], 'max_hp': 68, 'entering_hp': 56, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Jaw Worm', 'potion_used': False, 'floor': 4, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'WheelKick', 'Perseverance', 'BowlingBash'], 'relics': ['Snecko Eye'], 'max_hp': 68, 'entering_hp': 56, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Exordium Wildlife', 'potion_used': False, 'floor': 5, 'damage_taken': 9},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'WheelKick', 'Perseverance', 'BowlingBash', 'InnerPeace'], 'relics': ['Snecko Eye'], 'max_hp': 68, 'entering_hp': 47, 'character': 'WATCHER', 'ascension': 20, 'enemies': '2 Fungi Beasts', 'potion_used': False, 'floor': 7, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'WheelKick', 'Perseverance', 'BowlingBash', 'InnerPeace', 'Swivel'], 'relics': ['Snecko Eye'], 'max_hp': 68, 'entering_hp': 47, 'character': 'WATCHER', 'ascension': 20, 'enemies': '3 Sentries', 'potion_used': True, 'floor': 8, 'damage_taken': 10},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'WheelKick', 'Perseverance', 'BowlingBash', 'InnerPeace', 'Swivel', 'Study'], 'relics': ['Snecko Eye', 'CeramicFish', 'Smiling Mask', 'ClockworkSouvenir', 'Blood Vial'], 'max_hp': 68, 'entering_hp': 59, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Slime Boss', 'potion_used': False, 'floor': 16, 'damage_taken': 59}],
#        dtype=object),
#  array([{'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'FlyingSleeves'], 'relics': ['PureWater'], 'max_hp': 73, 'entering_hp': 54, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Small Slimes', 'potion_used': False, 'floor': 4, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'FlyingSleeves', 'BowlingBash'], 'relics': ['PureWater'], 'max_hp': 73, 'entering_hp': 47, 'character': 'WATCHER', 'ascension': 20, 'enemies': '3 Sentries', 'potion_used': False, 'floor': 7, 'damage_taken': 35},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'FlyingSleeves', 'BowlingBash', 'Wireheading'], 'relics': ['PureWater', 'Mummified Hand', 'Omamori'], 'max_hp': 73, 'entering_hp': 33, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Jaw Worm', 'potion_used': False, 'floor': 10, 'damage_taken': 2},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'FlyingSleeves', 'BowlingBash', 'Wireheading', 'InnerPeace'], 'relics': ['PureWater', 'Mummified Hand', 'Omamori'], 'max_hp': 73, 'entering_hp': 31, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Blue Slaver', 'potion_used': False, 'floor': 11, 'damage_taken': 13},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'FlyingSleeves', 'BowlingBash', 'Wireheading', 'InnerPeace', 'WindmillStrike'], 'relics': ['PureWater', 'Mummified Hand', 'Omamori'], 'max_hp': 73, 'entering_hp': 18, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Lagavulin', 'potion_used': False, 'floor': 12, 'damage_taken': 13},
#         {'cards': ['Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'FlyingSleeves', 'BowlingBash', 'Wireheading', 'InnerPeace', 'WindmillStrike', 'Sanctity'], 'relics': ['PureWater', 'Mummified Hand', 'Omamori', 'Eternal Feather', 'PreservedInsect'], 'max_hp': 73, 'entering_hp': 5, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Gremlin Gang', 'potion_used': True, 'floor': 14, 'damage_taken': 5}],
#        dtype=object),
#  array([{'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'Protect'], 'relics': ['PureWater', 'ClockworkSouvenir'], 'max_hp': 74, 'entering_hp': 50, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Jaw Worm', 'potion_used': False, 'floor': 4, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'Protect', 'Swivel'], 'relics': ['PureWater', 'ClockworkSouvenir'], 'max_hp': 74, 'entering_hp': 50, 'character': 'WATCHER', 'ascension': 20, 'enemies': '2 Louse', 'potion_used': False, 'floor': 5, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'Protect', 'Swivel', 'Swivel'], 'relics': ['PureWater', 'ClockworkSouvenir'], 'max_hp': 74, 'entering_hp': 50, 'character': 'WATCHER', 'ascension': 20, 'enemies': '3 Sentries', 'potion_used': True, 'floor': 7, 'damage_taken': 32},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'Protect', 'Swivel', 'Swivel', 'Sanctity'], 'relics': ['PureWater', 'ClockworkSouvenir', 'Shovel'], 'max_hp': 74, 'entering_hp': 18, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Red Slaver', 'potion_used': False, 'floor': 8, 'damage_taken': 5},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'Protect', 'Swivel', 'Swivel', 'Sanctity', 'Consecrate'], 'relics': ['PureWater', 'ClockworkSouvenir', 'Shovel', 'HornCleat', 'Frozen Egg 2'], 'max_hp': 74, 'entering_hp': 13, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Exordium Wildlife', 'potion_used': False, 'floor': 12, 'damage_taken': 5},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'Protect', 'Swivel', 'Swivel', 'Sanctity', 'Consecrate', 'LikeWater', 'CutThroughFate'], 'relics': ['PureWater', 'ClockworkSouvenir', 'Shovel', 'HornCleat', 'Frozen Egg 2'], 'max_hp': 74, 'entering_hp': 30, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Slime Boss', 'potion_used': True, 'floor': 16, 'damage_taken': 30}],
#        dtype=object),
#  array([{'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'ReachHeaven'], 'relics': ['Black Star', 'Golden Idol'], 'max_hp': 62, 'entering_hp': 57, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Cultist', 'potion_used': False, 'floor': 3, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'ReachHeaven', 'Swivel', 'BattleHymn'], 'relics': ['Black Star', 'Golden Idol'], 'max_hp': 62, 'entering_hp': 57, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Jaw Worm', 'potion_used': False, 'floor': 5, 'damage_taken': 4},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'ReachHeaven', 'Swivel', 'BattleHymn', 'Protect'], 'relics': ['Black Star', 'Golden Idol'], 'max_hp': 62, 'entering_hp': 53, 'character': 'WATCHER', 'ascension': 20, 'enemies': '3 Sentries', 'potion_used': True, 'floor': 7, 'damage_taken': 10},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'ReachHeaven', 'Swivel', 'BattleHymn', 'Protect', 'TalkToTheHand'], 'relics': ['Black Star', 'Golden Idol', 'Art of War', 'Oddly Smooth Stone', 'Bronze Scales'], 'max_hp': 62, 'entering_hp': 43, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Lagavulin', 'potion_used': True, 'floor': 11, 'damage_taken': 1},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'ReachHeaven', 'Swivel', 'BattleHymn', 'Protect', 'TalkToTheHand', 'CutThroughFate'], 'relics': ['Black Star', 'Golden Idol', 'Art of War', 'Oddly Smooth Stone', 'Bronze Scales', 'Molten Egg 2', 'Toxic Egg 2'], 'max_hp': 62, 'entering_hp': 42, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Gremlin Nob', 'potion_used': False, 'floor': 13, 'damage_taken': -5},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'ReachHeaven', 'Swivel', 'BattleHymn', 'Protect', 'TalkToTheHand', 'CutThroughFate', 'InnerPeace'], 'relics': ['Black Star', 'Golden Idol', 'Art of War', 'Oddly Smooth Stone', 'Bronze Scales', 'Molten Egg 2', 'Toxic Egg 2', 'Strawberry', 'Mummified Hand'], 'max_hp': 69, 'entering_hp': 47, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Exordium Thugs', 'potion_used': False, 'floor': 14, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'ReachHeaven', 'Swivel', 'BattleHymn', 'Protect', 'TalkToTheHand', 'CutThroughFate', 'InnerPeace', 'Swivel'], 'relics': ['Black Star', 'Golden Idol', 'Art of War', 'Oddly Smooth Stone', 'Bronze Scales', 'Molten Egg 2', 'Toxic Egg 2', 'Strawberry', 'Mummified Hand'], 'max_hp': 69, 'entering_hp': 47, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'The Guardian', 'potion_used': False, 'floor': 16, 'damage_taken': 15},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'ReachHeaven', 'Swivel', 'BattleHymn', 'Protect', 'TalkToTheHand', 'CutThroughFate', 'InnerPeace', 'Swivel', 'Wish'], 'relics': ['Black Star', 'Golden Idol', 'Art of War', 'Oddly Smooth Stone', 'Bronze Scales', 'Molten Egg 2', 'Toxic Egg 2', 'Strawberry', 'Mummified Hand', 'Snecko Eye'], 'max_hp': 69, 'entering_hp': 60, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Shell Parasite', 'potion_used': False, 'floor': 18, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'ReachHeaven', 'Swivel', 'BattleHymn', 'Protect', 'TalkToTheHand', 'CutThroughFate', 'InnerPeace', 'Swivel', 'Wish', 'LikeWater'], 'relics': ['Black Star', 'Golden Idol', 'Art of War', 'Oddly Smooth Stone', 'Bronze Scales', 'Molten Egg 2', 'Toxic Egg 2', 'Strawberry', 'Mummified Hand', 'Snecko Eye', 'Orichalcum'], 'max_hp': 69, 'entering_hp': 60, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Gremlin Leader', 'potion_used': True, 'floor': 23, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'ReachHeaven', 'Swivel', 'BattleHymn', 'Protect', 'TalkToTheHand', 'CutThroughFate', 'InnerPeace', 'Swivel', 'Wish', 'LikeWater', 'Wallop', 'Ragnarok'], 'relics': ['Black Star', 'Golden Idol', 'Art of War', 'Oddly Smooth Stone', 'Bronze Scales', 'Molten Egg 2', 'Toxic Egg 2', 'Strawberry', 'Mummified Hand', 'Snecko Eye', 'Orichalcum', 'Happy Flower', 'The Courier', 'Bag of Preparation'], 'max_hp': 69, 'entering_hp': 60, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Slavers', 'potion_used': False, 'floor': 27, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'ReachHeaven', 'Swivel', 'BattleHymn', 'Protect', 'TalkToTheHand', 'CutThroughFate', 'InnerPeace', 'Swivel', 'Wish', 'LikeWater', 'Wallop', 'Ragnarok', 'EmptyFist'], 'relics': ['Black Star', 'Golden Idol', 'Art of War', 'Oddly Smooth Stone', 'Bronze Scales', 'Molten Egg 2', 'Toxic Egg 2', 'Strawberry', 'Mummified Hand', 'Snecko Eye', 'Orichalcum', 'Happy Flower', 'The Courier', 'Bag of Preparation', 'CeramicFish', 'Bag of Marbles'], 'max_hp': 69, 'entering_hp': 60, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Spheric Guardian', 'potion_used': False, 'floor': 28, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'ReachHeaven', 'Swivel', 'BattleHymn', 'Protect', 'TalkToTheHand', 'CutThroughFate', 'InnerPeace', 'Swivel', 'Wish', 'LikeWater', 'Wallop', 'Ragnarok', 'EmptyFist', 'Halt'], 'relics': ['Black Star', 'Golden Idol', 'Art of War', 'Oddly Smooth Stone', 'Bronze Scales', 'Molten Egg 2', 'Toxic Egg 2', 'Strawberry', 'Mummified Hand', 'Snecko Eye', 'Orichalcum', 'Happy Flower', 'The Courier', 'Bag of Preparation', 'CeramicFish', 'Bag of Marbles'], 'max_hp': 69, 'entering_hp': 60, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Gremlin Leader', 'potion_used': False, 'floor': 29, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'ReachHeaven', 'Swivel', 'BattleHymn', 'Protect', 'TalkToTheHand', 'CutThroughFate', 'InnerPeace', 'Swivel', 'Wish', 'LikeWater', 'Wallop', 'Ragnarok', 'EmptyFist', 'Halt', 'Wallop'], 'relics': ['Black Star', 'Golden Idol', 'Art of War', 'Oddly Smooth Stone', 'Bronze Scales', 'Molten Egg 2', 'Toxic Egg 2', 'Strawberry', 'Mummified Hand', 'Snecko Eye', 'Orichalcum', 'Happy Flower', 'The Courier', 'Bag of Preparation', 'CeramicFish', 'Bag of Marbles', 'Akabeko', 'Darkstone Periapt'], 'max_hp': 69, 'entering_hp': 60, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Cultist and Chosen', 'potion_used': False, 'floor': 31, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'ReachHeaven', 'Swivel', 'BattleHymn', 'Protect', 'TalkToTheHand', 'CutThroughFate', 'InnerPeace', 'Swivel', 'Wish', 'LikeWater', 'Wallop', 'Ragnarok', 'EmptyFist', 'Halt', 'Wallop', 'FearNoEvil'], 'relics': ['Black Star', 'Golden Idol', 'Art of War', 'Oddly Smooth Stone', 'Bronze Scales', 'Molten Egg 2', 'Toxic Egg 2', 'Strawberry', 'Mummified Hand', 'Snecko Eye', 'Orichalcum', 'Happy Flower', 'The Courier', 'Bag of Preparation', 'CeramicFish', 'Bag of Marbles', 'Akabeko', 'Darkstone Periapt'], 'max_hp': 69, 'entering_hp': 60, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Collector', 'potion_used': False, 'floor': 33, 'damage_taken': 19},
#         {'cards': ['Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'ReachHeaven', 'Swivel', 'BattleHymn', 'Protect', 'TalkToTheHand', 'CutThroughFate', 'InnerPeace', 'Swivel', 'Wish', 'LikeWater', 'Wallop', 'Ragnarok', 'EmptyFist', 'Halt', 'Wallop', 'FearNoEvil', 'SpiritShield'], 'relics': ['Black Star', 'Golden Idol', 'Art of War', 'Oddly Smooth Stone', 'Bronze Scales', 'Molten Egg 2', 'Toxic Egg 2', 'Strawberry', 'Mummified Hand', 'Snecko Eye', 'Orichalcum', 'Happy Flower', 'The Courier', 'Bag of Preparation', 'CeramicFish', 'Bag of Marbles', 'Akabeko', 'Darkstone Periapt', 'Coffee Dripper'], 'max_hp': 69, 'entering_hp': 62, 'character': 'WATCHER', 'ascension': 20, 'enemies': '3 Shapes', 'potion_used': False, 'floor': 35, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'ReachHeaven', 'Swivel', 'BattleHymn', 'Protect', 'TalkToTheHand', 'CutThroughFate', 'InnerPeace', 'Swivel', 'Wish', 'LikeWater', 'Wallop', 'Ragnarok', 'EmptyFist', 'Halt', 'Wallop', 'FearNoEvil', 'SpiritShield', 'Protect'], 'relics': ['Black Star', 'Golden Idol', 'Art of War', 'Oddly Smooth Stone', 'Bronze Scales', 'Molten Egg 2', 'Toxic Egg 2', 'Strawberry', 'Mummified Hand', 'Snecko Eye', 'Orichalcum', 'Happy Flower', 'The Courier', 'Bag of Preparation', 'CeramicFish', 'Bag of Marbles', 'Akabeko', 'Darkstone Periapt', 'Coffee Dripper'], 'max_hp': 69, 'entering_hp': 62, 'character': 'WATCHER', 'ascension': 20, 'enemies': '3 Darklings', 'potion_used': False, 'floor': 38, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'ReachHeaven', 'Swivel', 'BattleHymn', 'Protect', 'TalkToTheHand', 'CutThroughFate', 'InnerPeace', 'Swivel', 'Wish', 'LikeWater', 'Wallop', 'Ragnarok', 'EmptyFist', 'Halt', 'Wallop', 'FearNoEvil', 'SpiritShield', 'Protect'], 'relics': ['Black Star', 'Golden Idol', 'Art of War', 'Oddly Smooth Stone', 'Bronze Scales', 'Molten Egg 2', 'Toxic Egg 2', 'Strawberry', 'Mummified Hand', 'Snecko Eye', 'Orichalcum', 'Happy Flower', 'The Courier', 'Bag of Preparation', 'CeramicFish', 'Bag of Marbles', 'Akabeko', 'Darkstone Periapt', 'Coffee Dripper', 'PreservedInsect', "Lee's Waffle", 'Anchor'], 'max_hp': 76, 'entering_hp': 76, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Nemesis', 'potion_used': False, 'floor': 40, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'ReachHeaven', 'Swivel', 'BattleHymn', 'Protect', 'TalkToTheHand', 'CutThroughFate', 'InnerPeace', 'Swivel', 'Wish', 'LikeWater', 'Wallop', 'Ragnarok', 'EmptyFist', 'Halt', 'Wallop', 'FearNoEvil', 'SpiritShield', 'Protect', 'Sanctity'], 'relics': ['Black Star', 'Golden Idol', 'Art of War', 'Oddly Smooth Stone', 'Bronze Scales', 'Molten Egg 2', 'Toxic Egg 2', 'Strawberry', 'Mummified Hand', 'Snecko Eye', 'Orichalcum', 'Happy Flower', 'The Courier', 'Bag of Preparation', 'CeramicFish', 'Bag of Marbles', 'Akabeko', 'Darkstone Periapt', 'Coffee Dripper', 'PreservedInsect', "Lee's Waffle", 'Anchor', 'Shovel', 'Eternal Feather'], 'max_hp': 76, 'entering_hp': 76, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Jaw Worm Horde', 'potion_used': False, 'floor': 41, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'ReachHeaven', 'Swivel', 'BattleHymn', 'Protect', 'TalkToTheHand', 'CutThroughFate', 'InnerPeace', 'Swivel', 'Wish', 'LikeWater', 'Wallop', 'Ragnarok', 'EmptyFist', 'Halt', 'Wallop', 'FearNoEvil', 'SpiritShield', 'Protect', 'Sanctity'], 'relics': ['Black Star', 'Golden Idol', 'Art of War', 'Oddly Smooth Stone', 'Bronze Scales', 'Molten Egg 2', 'Toxic Egg 2', 'Strawberry', 'Mummified Hand', 'Snecko Eye', 'Orichalcum', 'Happy Flower', 'The Courier', 'Bag of Preparation', 'CeramicFish', 'Bag of Marbles', 'Akabeko', 'Darkstone Periapt', 'Coffee Dripper', 'PreservedInsect', "Lee's Waffle", 'Anchor', 'Shovel', 'Eternal Feather'], 'max_hp': 76, 'entering_hp': 76, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Giant Head', 'potion_used': False, 'floor': 42, 'damage_taken': -2},
#         {'cards': ['Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'ReachHeaven', 'Swivel', 'BattleHymn', 'Protect', 'TalkToTheHand', 'CutThroughFate', 'InnerPeace', 'Swivel', 'Wish', 'LikeWater', 'Wallop', 'Ragnarok', 'EmptyFist', 'Halt', 'Wallop', 'FearNoEvil', 'SpiritShield', 'Protect', 'Sanctity'], 'relics': ['Black Star', 'Golden Idol', 'Art of War', 'Oddly Smooth Stone', 'Bronze Scales', 'Molten Egg 2', 'Toxic Egg 2', 'Strawberry', 'Mummified Hand', 'Snecko Eye', 'Orichalcum', 'Happy Flower', 'The Courier', 'Bag of Preparation', 'CeramicFish', 'Bag of Marbles', 'Akabeko', 'Darkstone Periapt', 'Coffee Dripper', 'PreservedInsect', "Lee's Waffle", 'Anchor', 'Shovel', 'Eternal Feather', 'Singing Bowl', 'Bottled Tornado'], 'max_hp': 78, 'entering_hp': 78, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Maw', 'potion_used': False, 'floor': 44, 'damage_taken': -2},
#         {'cards': ['Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'ReachHeaven', 'Swivel', 'BattleHymn', 'Protect', 'TalkToTheHand', 'CutThroughFate', 'InnerPeace', 'Swivel', 'Wish', 'LikeWater', 'Wallop', 'Ragnarok', 'EmptyFist', 'Halt', 'Wallop', 'FearNoEvil', 'SpiritShield', 'Protect', 'Sanctity'], 'relics': ['Black Star', 'Golden Idol', 'Art of War', 'Oddly Smooth Stone', 'Bronze Scales', 'Molten Egg 2', 'Toxic Egg 2', 'Strawberry', 'Mummified Hand', 'Snecko Eye', 'Orichalcum', 'Happy Flower', 'The Courier', 'Bag of Preparation', 'CeramicFish', 'Bag of Marbles', 'Akabeko', 'Darkstone Periapt', 'Coffee Dripper', 'PreservedInsect', "Lee's Waffle", 'Anchor', 'Shovel', 'Eternal Feather', 'Singing Bowl', 'Bottled Tornado'], 'max_hp': 80, 'entering_hp': 80, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Transient', 'potion_used': False, 'floor': 46, 'damage_taken': -2},
#         {'cards': ['Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'ReachHeaven', 'Swivel', 'BattleHymn', 'Protect', 'TalkToTheHand', 'CutThroughFate', 'InnerPeace', 'Swivel', 'Wish', 'LikeWater', 'Wallop', 'Ragnarok', 'EmptyFist', 'Halt', 'Wallop', 'FearNoEvil', 'SpiritShield', 'Protect', 'Sanctity'], 'relics': ['Black Star', 'Golden Idol', 'Art of War', 'Oddly Smooth Stone', 'Bronze Scales', 'Molten Egg 2', 'Toxic Egg 2', 'Strawberry', 'Mummified Hand', 'Snecko Eye', 'Orichalcum', 'Happy Flower', 'The Courier', 'Bag of Preparation', 'CeramicFish', 'Bag of Marbles', 'Akabeko', 'Darkstone Periapt', 'Coffee Dripper', 'PreservedInsect', "Lee's Waffle", 'Anchor', 'Shovel', 'Eternal Feather', 'Singing Bowl', 'Bottled Tornado'], 'max_hp': 82, 'entering_hp': 82, 'character': 'WATCHER', 'ascension': 20, 'enemies': '3 Darklings', 'potion_used': False, 'floor': 47, 'damage_taken': 14},
#         {'cards': ['Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'ReachHeaven', 'Swivel', 'BattleHymn', 'Protect', 'TalkToTheHand', 'CutThroughFate', 'InnerPeace', 'Swivel', 'Wish', 'LikeWater', 'Wallop', 'Ragnarok', 'EmptyFist', 'Halt', 'Wallop', 'FearNoEvil', 'SpiritShield', 'Protect', 'Sanctity'], 'relics': ['Black Star', 'Golden Idol', 'Art of War', 'Oddly Smooth Stone', 'Bronze Scales', 'Molten Egg 2', 'Toxic Egg 2', 'Strawberry', 'Mummified Hand', 'Snecko Eye', 'Orichalcum', 'Happy Flower', 'The Courier', 'Bag of Preparation', 'CeramicFish', 'Bag of Marbles', 'Akabeko', 'Darkstone Periapt', 'Coffee Dripper', 'PreservedInsect', "Lee's Waffle", 'Anchor', 'Shovel', 'Eternal Feather', 'Singing Bowl', 'Bottled Tornado'], 'max_hp': 84, 'entering_hp': 68, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Nemesis', 'potion_used': False, 'floor': 48, 'damage_taken': -2},
#         {'cards': ['Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'ReachHeaven', 'Swivel', 'BattleHymn', 'Protect', 'TalkToTheHand', 'CutThroughFate', 'InnerPeace', 'Swivel', 'Wish', 'LikeWater', 'Wallop', 'Ragnarok', 'EmptyFist', 'Halt', 'Wallop', 'FearNoEvil', 'SpiritShield', 'Protect', 'Sanctity'], 'relics': ['Black Star', 'Golden Idol', 'Art of War', 'Oddly Smooth Stone', 'Bronze Scales', 'Molten Egg 2', 'Toxic Egg 2', 'Strawberry', 'Mummified Hand', 'Snecko Eye', 'Orichalcum', 'Happy Flower', 'The Courier', 'Bag of Preparation', 'CeramicFish', 'Bag of Marbles', 'Akabeko', 'Darkstone Periapt', 'Coffee Dripper', 'PreservedInsect', "Lee's Waffle", 'Anchor', 'Shovel', 'Eternal Feather', 'Singing Bowl', 'Bottled Tornado', 'FossilizedHelix', 'Whetstone', 'Sundial'], 'max_hp': 86, 'entering_hp': 85, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Donu and Deca', 'potion_used': False, 'floor': 50, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'ReachHeaven', 'Swivel', 'BattleHymn', 'Protect', 'TalkToTheHand', 'CutThroughFate', 'InnerPeace', 'Swivel', 'Wish', 'LikeWater', 'Wallop', 'Ragnarok', 'EmptyFist', 'Halt', 'Wallop', 'FearNoEvil', 'SpiritShield', 'Protect', 'Sanctity'], 'relics': ['Black Star', 'Golden Idol', 'Art of War', 'Oddly Smooth Stone', 'Bronze Scales', 'Molten Egg 2', 'Toxic Egg 2', 'Strawberry', 'Mummified Hand', 'Snecko Eye', 'Orichalcum', 'Happy Flower', 'The Courier', 'Bag of Preparation', 'CeramicFish', 'Bag of Marbles', 'Akabeko', 'Darkstone Periapt', 'Coffee Dripper', 'PreservedInsect', "Lee's Waffle", 'Anchor', 'Shovel', 'Eternal Feather', 'Singing Bowl', 'Bottled Tornado', 'FossilizedHelix', 'Whetstone', 'Sundial'], 'max_hp': 86, 'entering_hp': 85, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Awakened One', 'potion_used': False, 'floor': 51, 'damage_taken': 17},
#         {'cards': ['Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'ReachHeaven', 'Swivel', 'BattleHymn', 'Protect', 'TalkToTheHand', 'CutThroughFate', 'InnerPeace', 'Swivel', 'Wish', 'LikeWater', 'Wallop', 'Ragnarok', 'EmptyFist', 'Halt', 'Wallop', 'FearNoEvil', 'SpiritShield', 'Protect', 'Sanctity', 'Perseverance', 'SpiritShield'], 'relics': ['Black Star', 'Golden Idol', 'Art of War', 'Oddly Smooth Stone', 'Bronze Scales', 'Molten Egg 2', 'Toxic Egg 2', 'Strawberry', 'Mummified Hand', 'Snecko Eye', 'Orichalcum', 'Happy Flower', 'The Courier', 'Bag of Preparation', 'CeramicFish', 'Bag of Marbles', 'Akabeko', 'Darkstone Periapt', 'Coffee Dripper', 'PreservedInsect', "Lee's Waffle", 'Anchor', 'Shovel', 'Eternal Feather', 'Singing Bowl', 'Bottled Tornado', 'FossilizedHelix', 'Whetstone', 'Sundial', 'Shuriken'], 'max_hp': 86, 'entering_hp': 86, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Shield and Spear', 'potion_used': False, 'floor': 55, 'damage_taken': 40},
#         {'cards': ['Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'ReachHeaven', 'Swivel', 'BattleHymn', 'Protect', 'TalkToTheHand', 'CutThroughFate', 'InnerPeace', 'Swivel', 'Wish', 'LikeWater', 'Wallop', 'Ragnarok', 'EmptyFist', 'Halt', 'Wallop', 'FearNoEvil', 'SpiritShield', 'Protect', 'Sanctity', 'Perseverance', 'SpiritShield', 'Perseverance'], 'relics': ['Black Star', 'Golden Idol', 'Art of War', 'Oddly Smooth Stone', 'Bronze Scales', 'Molten Egg 2', 'Toxic Egg 2', 'Strawberry', 'Mummified Hand', 'Snecko Eye', 'Orichalcum', 'Happy Flower', 'The Courier', 'Bag of Preparation', 'CeramicFish', 'Bag of Marbles', 'Akabeko', 'Darkstone Periapt', 'Coffee Dripper', 'PreservedInsect', "Lee's Waffle", 'Anchor', 'Shovel', 'Eternal Feather', 'Singing Bowl', 'Bottled Tornado', 'FossilizedHelix', 'Whetstone', 'Sundial', 'Shuriken', 'Letter Opener', 'Lizard Tail'], 'max_hp': 86, 'entering_hp': 46, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'The Heart', 'potion_used': True, 'floor': 56, 'damage_taken': 45}],
#        dtype=object),
#  array([{'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'FlurryOfBlows'], 'relics': ['Sozu'], 'max_hp': 68, 'entering_hp': 61, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Cultist', 'potion_used': False, 'floor': 2, 'damage_taken': 6},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'FlurryOfBlows', 'FlyingSleeves'], 'relics': ['Sozu'], 'max_hp': 68, 'entering_hp': 55, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Jaw Worm', 'potion_used': False, 'floor': 4, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'FlurryOfBlows', 'FlyingSleeves', 'SandsOfTime'], 'relics': ['Sozu'], 'max_hp': 68, 'entering_hp': 55, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Large Slime', 'potion_used': False, 'floor': 5, 'damage_taken': 16},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'FlurryOfBlows', 'FlyingSleeves', 'SandsOfTime'], 'relics': ['Sozu'], 'max_hp': 68, 'entering_hp': 39, 'character': 'WATCHER', 'ascension': 20, 'enemies': '3 Sentries', 'potion_used': False, 'floor': 7, 'damage_taken': 17},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'FlurryOfBlows', 'FlyingSleeves', 'SandsOfTime', 'Halt', 'FearNoEvil'], 'relics': ['Sozu', 'CeramicFish', 'Anchor', 'Golden Idol'], 'max_hp': 62, 'entering_hp': 22, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Gremlin Nob', 'potion_used': False, 'floor': 11, 'damage_taken': 3},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'FlurryOfBlows', 'FlyingSleeves', 'SandsOfTime', 'Halt', 'FearNoEvil', 'SashWhip'], 'relics': ['Sozu', 'CeramicFish', 'Anchor', 'Golden Idol', 'Frozen Egg 2'], 'max_hp': 62, 'entering_hp': 19, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Gremlin Gang', 'potion_used': False, 'floor': 14, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'FlurryOfBlows', 'FlyingSleeves', 'SandsOfTime', 'Halt', 'FearNoEvil', 'SashWhip', 'Sanctity'], 'relics': ['Sozu', 'CeramicFish', 'Anchor', 'Golden Idol', 'Frozen Egg 2'], 'max_hp': 62, 'entering_hp': 19, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'The Guardian', 'potion_used': False, 'floor': 16, 'damage_taken': 19}],
#        dtype=object),
#  array([{'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'Conclude'], 'relics': ['PureWater', 'Juzu Bracelet'], 'max_hp': 62, 'entering_hp': 61, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Cultist', 'potion_used': False, 'floor': 3, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'Conclude', 'Wallop'], 'relics': ['PureWater', 'Juzu Bracelet'], 'max_hp': 62, 'entering_hp': 61, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Small Slimes', 'potion_used': False, 'floor': 4, 'damage_taken': 5},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'Conclude', 'Wallop', 'ClearTheMind'], 'relics': ['PureWater', 'Juzu Bracelet'], 'max_hp': 62, 'entering_hp': 56, 'character': 'WATCHER', 'ascension': 20, 'enemies': '3 Louse', 'potion_used': False, 'floor': 5, 'damage_taken': 2},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'Conclude', 'Wallop', 'ClearTheMind', 'LikeWater'], 'relics': ['PureWater', 'Juzu Bracelet'], 'max_hp': 62, 'entering_hp': 54, 'character': 'WATCHER', 'ascension': 20, 'enemies': '3 Sentries', 'potion_used': True, 'floor': 6, 'damage_taken': 5},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'Conclude', 'Wallop', 'ClearTheMind', 'LikeWater', 'Evaluate'], 'relics': ['PureWater', 'Juzu Bracelet', 'Potion Belt'], 'max_hp': 62, 'entering_hp': 49, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Looter', 'potion_used': False, 'floor': 8, 'damage_taken': 6},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'Conclude', 'Wallop', 'ClearTheMind', 'LikeWater', 'Evaluate'], 'relics': ['PureWater', 'Juzu Bracelet', 'Potion Belt', 'CeramicFish'], 'max_hp': 62, 'entering_hp': 43, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Lagavulin', 'potion_used': False, 'floor': 10, 'damage_taken': 25},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'Conclude', 'Wallop', 'ClearTheMind', 'LikeWater', 'Evaluate', 'SashWhip'], 'relics': ['PureWater', 'Juzu Bracelet', 'Potion Belt', 'CeramicFish', 'Bottled Tornado'], 'max_hp': 62, 'entering_hp': 18, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Gremlin Gang', 'potion_used': False, 'floor': 11, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'Conclude', 'Wallop', 'ClearTheMind', 'LikeWater', 'Evaluate', 'SashWhip', 'MentalFortress', 'DevaForm'], 'relics': ['PureWater', 'Juzu Bracelet', 'Potion Belt', 'CeramicFish', 'Bottled Tornado', 'Eternal Feather'], 'max_hp': 62, 'entering_hp': 18, 'character': 'WATCHER', 'ascension': 20, 'enemies': '3 Sentries', 'potion_used': True, 'floor': 14, 'damage_taken': 18}],
#        dtype=object),
#  array([{'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'Halt'], 'relics': ['PureWater', 'NeowsBlessing'], 'max_hp': 68, 'entering_hp': 61, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Jaw Worm', 'potion_used': False, 'floor': 2, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'Halt', 'Halt', 'Pain'], 'relics': ['PureWater', 'NeowsBlessing', 'WarpedTongs'], 'max_hp': 68, 'entering_hp': 61, 'character': 'WATCHER', 'ascension': 20, 'enemies': '2 Louse', 'potion_used': False, 'floor': 4, 'damage_taken': 2},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'Halt', 'Halt', 'CrushJoints', 'WheelKick'], 'relics': ['PureWater', 'NeowsBlessing', 'WarpedTongs'], 'max_hp': 68, 'entering_hp': 59, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Blue Slaver', 'potion_used': False, 'floor': 6, 'damage_taken': 5},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'Halt', 'Halt', 'CrushJoints', 'WheelKick', 'FlyingSleeves'], 'relics': ['PureWater', 'NeowsBlessing', 'WarpedTongs', 'Potion Belt', 'Darkstone Periapt'], 'max_hp': 68, 'entering_hp': 43, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Lagavulin', 'potion_used': True, 'floor': 10, 'damage_taken': 17},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'Halt', 'Halt', 'CrushJoints', 'WheelKick', 'FlyingSleeves', 'Meditate'], 'relics': ['PureWater', 'NeowsBlessing', 'WarpedTongs', 'Potion Belt', 'Darkstone Periapt', 'Mummified Hand'], 'max_hp': 68, 'entering_hp': 35, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Exordium Thugs', 'potion_used': True, 'floor': 13, 'damage_taken': 11},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'Halt', 'Halt', 'CrushJoints', 'WheelKick', 'FlyingSleeves', 'Meditate', 'WaveOfTheHand'], 'relics': ['PureWater', 'NeowsBlessing', 'WarpedTongs', 'Potion Belt', 'Darkstone Periapt', 'Mummified Hand'], 'max_hp': 68, 'entering_hp': 24, 'character': 'WATCHER', 'ascension': 20, 'enemies': '3 Sentries', 'potion_used': True, 'floor': 14, 'damage_taken': 13},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'Halt', 'Halt', 'CrushJoints', 'WheelKick', 'FlyingSleeves', 'Meditate', 'WaveOfTheHand', 'Halt'], 'relics': ['PureWater', 'NeowsBlessing', 'WarpedTongs', 'Potion Belt', 'Darkstone Periapt', 'Mummified Hand', 'Bag of Marbles'], 'max_hp': 68, 'entering_hp': 11, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'The Guardian', 'potion_used': False, 'floor': 16, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'Halt', 'Halt', 'CrushJoints', 'WheelKick', 'FlyingSleeves', 'Meditate', 'WaveOfTheHand', 'Halt', 'Ragnarok'], 'relics': ['PureWater', 'NeowsBlessing', 'WarpedTongs', 'Potion Belt', 'Darkstone Periapt', 'Mummified Hand', 'Bag of Marbles', 'Empty Cage'], 'max_hp': 68, 'entering_hp': 54, 'character': 'WATCHER', 'ascension': 20, 'enemies': '2 Thieves', 'potion_used': True, 'floor': 18, 'damage_taken': 3},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'Halt', 'Halt', 'CrushJoints', 'WheelKick', 'FlyingSleeves', 'Meditate', 'WaveOfTheHand', 'Halt', 'Ragnarok', 'EmptyFist', 'Wallop'], 'relics': ['PureWater', 'NeowsBlessing', 'WarpedTongs', 'Potion Belt', 'Darkstone Periapt', 'Mummified Hand', 'Bag of Marbles', 'Empty Cage'], 'max_hp': 68, 'entering_hp': 51, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Chosen', 'potion_used': False, 'floor': 20, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'Halt', 'Halt', 'CrushJoints', 'WheelKick', 'FlyingSleeves', 'Meditate', 'WaveOfTheHand', 'Halt', 'Ragnarok', 'EmptyFist', 'Wallop', 'RitualDagger'], 'relics': ['PureWater', 'NeowsBlessing', 'WarpedTongs', 'Potion Belt', 'Darkstone Periapt', 'Mummified Hand', 'Bag of Marbles', 'Empty Cage', 'Frozen Egg 2'], 'max_hp': 68, 'entering_hp': 45, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Book of Stabbing', 'potion_used': False, 'floor': 24, 'damage_taken': 15},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'Halt', 'Halt', 'CrushJoints', 'WheelKick', 'FlyingSleeves', 'Meditate', 'WaveOfTheHand', 'Halt', 'Ragnarok', 'EmptyFist', 'Wallop', 'RitualDagger', 'Tantrum'], 'relics': ['PureWater', 'NeowsBlessing', 'WarpedTongs', 'Potion Belt', 'Darkstone Periapt', 'Mummified Hand', 'Bag of Marbles', 'Empty Cage', 'Frozen Egg 2', 'Pantograph', 'The Courier'], 'max_hp': 68, 'entering_hp': 18, 'character': 'WATCHER', 'ascension': 20, 'enemies': '3 Cultists', 'potion_used': True, 'floor': 28, 'damage_taken': 18}],
#        dtype=object),
#  array([{'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'EmptyMind'], 'relics': ['PureWater', 'NeowsBlessing', 'Question Card', 'CultistMask'], 'max_hp': 68, 'entering_hp': 50, 'character': 'WATCHER', 'ascension': 20, 'enemies': '2 Louse', 'potion_used': False, 'floor': 4, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'EmptyMind', 'Perseverance'], 'relics': ['PureWater', 'NeowsBlessing', 'Question Card', 'CultistMask'], 'max_hp': 68, 'entering_hp': 50, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Cultist', 'potion_used': False, 'floor': 5, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'EmptyMind', 'Perseverance'], 'relics': ['PureWater', 'NeowsBlessing', 'Question Card', 'CultistMask'], 'max_hp': 68, 'entering_hp': 50, 'character': 'WATCHER', 'ascension': 20, 'enemies': '3 Sentries', 'potion_used': True, 'floor': 6, 'damage_taken': 50}],
#        dtype=object),
#  array([{'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'CarveReality'], 'relics': ['Cursed Key'], 'max_hp': 68, 'entering_hp': 51, 'character': 'WATCHER', 'ascension': 20, 'enemies': '2 Louse', 'potion_used': False, 'floor': 2, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'CarveReality', 'FlurryOfBlows'], 'relics': ['Cursed Key'], 'max_hp': 68, 'entering_hp': 40, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Jaw Worm', 'potion_used': False, 'floor': 4, 'damage_taken': 4},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'CarveReality', 'FlurryOfBlows', 'Evaluate'], 'relics': ['Cursed Key'], 'max_hp': 68, 'entering_hp': 36, 'character': 'WATCHER', 'ascension': 20, 'enemies': '3 Louse', 'potion_used': False, 'floor': 5, 'damage_taken': 12},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'CarveReality', 'FlurryOfBlows', 'Evaluate', 'FearNoEvil'], 'relics': ['Cursed Key'], 'max_hp': 68, 'entering_hp': 24, 'character': 'WATCHER', 'ascension': 20, 'enemies': '3 Sentries', 'potion_used': False, 'floor': 7, 'damage_taken': 4},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'CarveReality', 'FlurryOfBlows', 'Evaluate', 'FearNoEvil', 'EmptyFist'], 'relics': ['Cursed Key', 'Shuriken'], 'max_hp': 68, 'entering_hp': 20, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Lagavulin', 'potion_used': False, 'floor': 10, 'damage_taken': 17},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'CarveReality', 'FlurryOfBlows', 'Evaluate', 'FearNoEvil', 'EmptyFist', 'CarveReality'], 'relics': ['Cursed Key', 'Shuriken', 'Pen Nib'], 'max_hp': 68, 'entering_hp': 3, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Exordium Thugs', 'potion_used': False, 'floor': 11, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'CarveReality', 'FlurryOfBlows', 'Evaluate', 'FearNoEvil', 'EmptyFist', 'CarveReality', 'ClearTheMind'], 'relics': ['Cursed Key', 'Shuriken', 'Pen Nib'], 'max_hp': 68, 'entering_hp': 3, 'character': 'WATCHER', 'ascension': 20, 'enemies': '3 Sentries', 'potion_used': True, 'floor': 12, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'CarveReality', 'FlurryOfBlows', 'Evaluate', 'FearNoEvil', 'EmptyFist', 'CarveReality', 'ClearTheMind', 'CrushJoints'], 'relics': ['Cursed Key', 'Shuriken', 'Pen Nib', 'MealTicket', 'PreservedInsect'], 'max_hp': 68, 'entering_hp': 38, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Slime Boss', 'potion_used': False, 'floor': 16, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'CarveReality', 'FlurryOfBlows', 'Evaluate', 'FearNoEvil', 'EmptyFist', 'CarveReality', 'ClearTheMind', 'CrushJoints', 'MasterReality'], 'relics': ['Cursed Key', 'Shuriken', 'Pen Nib', 'MealTicket', 'PreservedInsect', 'VioletLotus'], 'max_hp': 68, 'entering_hp': 61, 'character': 'WATCHER', 'ascension': 20, 'enemies': '3 Byrds', 'potion_used': False, 'floor': 18, 'damage_taken': 33},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'CarveReality', 'FlurryOfBlows', 'Evaluate', 'FearNoEvil', 'EmptyFist', 'CarveReality', 'ClearTheMind', 'CrushJoints', 'MasterReality', 'DeceiveReality'], 'relics': ['Cursed Key', 'Shuriken', 'Pen Nib', 'MealTicket', 'PreservedInsect', 'VioletLotus', 'Art of War'], 'max_hp': 68, 'entering_hp': 28, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Shell Parasite', 'potion_used': True, 'floor': 21, 'damage_taken': 18},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'CarveReality', 'FlurryOfBlows', 'Evaluate', 'FearNoEvil', 'EmptyFist', 'CarveReality', 'ClearTheMind', 'CrushJoints', 'MasterReality', 'DeceiveReality'], 'relics': ['Cursed Key', 'Shuriken', 'Pen Nib', 'MealTicket', 'PreservedInsect', 'VioletLotus', 'Art of War'], 'max_hp': 68, 'entering_hp': 10, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Snake Plant', 'potion_used': False, 'floor': 22, 'damage_taken': 10}],
#        dtype=object),
#  array([{'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'Halt'], 'relics': ['Runic Dome'], 'max_hp': 68, 'entering_hp': 49, 'character': 'WATCHER', 'ascension': 20, 'enemies': '2 Louse', 'potion_used': False, 'floor': 2, 'damage_taken': 5},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'Halt', 'Wallop', 'Trip'], 'relics': ['Runic Dome'], 'max_hp': 68, 'entering_hp': 44, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Jaw Worm', 'potion_used': False, 'floor': 4, 'damage_taken': 6},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'Halt', 'Wallop', 'Trip', 'Wallop'], 'relics': ['Runic Dome'], 'max_hp': 68, 'entering_hp': 38, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Gremlin Nob', 'potion_used': False, 'floor': 6, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'Halt', 'Wallop', 'Trip', 'Wallop', 'BattleHymn'], 'relics': ['Runic Dome', 'Vajra'], 'max_hp': 68, 'entering_hp': 38, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Large Slime', 'potion_used': False, 'floor': 7, 'damage_taken': 2},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'Halt', 'Wallop', 'Trip', 'Wallop', 'BattleHymn', 'Evaluate'], 'relics': ['Runic Dome', 'Vajra', 'Art of War', 'Golden Idol', 'Torii'], 'max_hp': 62, 'entering_hp': 36, 'character': 'WATCHER', 'ascension': 20, 'enemies': '3 Sentries', 'potion_used': False, 'floor': 12, 'damage_taken': 10},
# ...
#         {'cards': ['Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'BowlingBash', 'LikeWater', 'EmptyFist', 'CarveReality'], 'relics': ['PureWater', 'Mummified Hand'], 'max_hp': 73, 'entering_hp': 63, 'character': 'WATCHER', 'ascension': 20, 'enemies': '3 Sentries', 'potion_used': False, 'floor': 10, 'damage_taken': 2},
#         {'cards': ['Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'BowlingBash', 'LikeWater', 'EmptyFist', 'CarveReality', 'SashWhip'], 'relics': ['PureWater', 'Mummified Hand', 'Strawberry'], 'max_hp': 80, 'entering_hp': 61, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Lagavulin', 'potion_used': False, 'floor': 12, 'damage_taken': 8},
#         {'cards': ['Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'BowlingBash', 'LikeWater', 'EmptyFist', 'CarveReality', 'SashWhip', 'Wireheading'], 'relics': ['PureWater', 'Mummified Hand', 'Strawberry', 'Turnip'], 'max_hp': 80, 'entering_hp': 53, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Gremlin Nob', 'potion_used': False, 'floor': 14, 'damage_taken': 12},
#         {'cards': ['Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'BowlingBash', 'LikeWater', 'EmptyFist', 'CarveReality', 'SashWhip', 'Wireheading', 'Conclude'], 'relics': ['PureWater', 'Mummified Hand', 'Strawberry', 'Turnip', 'Yang'], 'max_hp': 80, 'entering_hp': 41, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Hexaghost', 'potion_used': False, 'floor': 16, 'damage_taken': 33},
#         {'cards': ['Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'BowlingBash', 'LikeWater', 'EmptyFist', 'CarveReality', 'SashWhip', 'Wireheading', 'Conclude', 'SpiritShield'], 'relics': ['PureWater', 'Mummified Hand', 'Strawberry', 'Turnip', 'Yang', 'VioletLotus'], 'max_hp': 80, 'entering_hp': 62, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Spheric Guardian', 'potion_used': False, 'floor': 18, 'damage_taken': 22},
#         {'cards': ['Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'BowlingBash', 'LikeWater', 'EmptyFist', 'CarveReality', 'SashWhip', 'Wireheading', 'Conclude', 'SpiritShield', 'Meditate'], 'relics': ['PureWater', 'Mummified Hand', 'Strawberry', 'Turnip', 'Yang', 'VioletLotus'], 'max_hp': 80, 'entering_hp': 40, 'character': 'WATCHER', 'ascension': 20, 'enemies': '2 Thieves', 'potion_used': False, 'floor': 19, 'damage_taken': 14},
#         {'cards': ['Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'BowlingBash', 'LikeWater', 'EmptyFist', 'CarveReality', 'SashWhip', 'Wireheading', 'Conclude', 'SpiritShield', 'Meditate'], 'relics': ['PureWater', 'Mummified Hand', 'Strawberry', 'Turnip', 'Yang', 'VioletLotus'], 'max_hp': 80, 'entering_hp': 26, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Snake Plant', 'potion_used': False, 'floor': 20, 'damage_taken': 23},
#         {'cards': ['Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'BowlingBash', 'LikeWater', 'EmptyFist', 'CarveReality', 'SashWhip', 'Wireheading', 'Conclude', 'SpiritShield', 'Meditate', 'JustLucky'], 'relics': ['PureWater', 'Mummified Hand', 'Strawberry', 'Turnip', 'Yang', 'VioletLotus'], 'max_hp': 80, 'entering_hp': 3, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Masked Bandits', 'potion_used': True, 'floor': 21, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'BowlingBash', 'LikeWater', 'EmptyFist', 'CarveReality', 'SashWhip', 'Wireheading', 'Conclude', 'SpiritShield', 'Meditate', 'JustLucky'], 'relics': ['PureWater', 'Mummified Hand', 'Strawberry', 'Turnip', 'Yang', 'VioletLotus', 'Red Mask'], 'max_hp': 80, 'entering_hp': 3, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Cultist and Chosen', 'potion_used': False, 'floor': 22, 'damage_taken': 3}],
#        dtype=object),
#  array([{'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'TalkToTheHand'], 'relics': ['PureWater'], 'max_hp': 68, 'entering_hp': 61, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Jaw Worm', 'potion_used': False, 'floor': 2, 'damage_taken': 2},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'TalkToTheHand', 'Consecrate'], 'relics': ['PureWater'], 'max_hp': 68, 'entering_hp': 59, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Cultist', 'potion_used': False, 'floor': 3, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'TalkToTheHand', 'Consecrate', 'ThirdEye', 'Vault', 'Wireheading'], 'relics': ['PureWater'], 'max_hp': 68, 'entering_hp': 52, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Gremlin Nob', 'potion_used': True, 'floor': 7, 'damage_taken': 43},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'TalkToTheHand', 'Consecrate', 'ThirdEye', 'Vault', 'Wireheading', 'Meditate'], 'relics': ['PureWater', 'Letter Opener'], 'max_hp': 68, 'entering_hp': 9, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Exordium Thugs', 'potion_used': False, 'floor': 8, 'damage_taken': 9}],
#        dtype=object),
#  array([{'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'FollowUp', 'PathToVictory'], 'relics': ['PureWater', 'Golden Idol'], 'max_hp': 74, 'entering_hp': 55, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Small Slimes', 'potion_used': False, 'floor': 5, 'damage_taken': 3},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'FollowUp', 'PathToVictory', 'ReachHeaven'], 'relics': ['PureWater', 'Golden Idol'], 'max_hp': 74, 'entering_hp': 30, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Lagavulin', 'potion_used': False, 'floor': 8, 'damage_taken': 18},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'FollowUp', 'PathToVictory', 'ReachHeaven', 'DeceiveReality'], 'relics': ['PureWater', 'Golden Idol', 'MawBank', 'PreservedInsect'], 'max_hp': 74, 'entering_hp': 23, 'character': 'WATCHER', 'ascension': 20, 'enemies': '3 Sentries', 'potion_used': False, 'floor': 12, 'damage_taken': 5},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'FollowUp', 'PathToVictory', 'ReachHeaven', 'DeceiveReality', 'ClearTheMind'], 'relics': ['PureWater', 'Golden Idol', 'MawBank', 'PreservedInsect', 'MealTicket'], 'max_hp': 74, 'entering_hp': 40, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Lagavulin', 'potion_used': False, 'floor': 14, 'damage_taken': 3},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'FollowUp', 'PathToVictory', 'ReachHeaven', 'DeceiveReality', 'ClearTheMind', 'Wireheading'], 'relics': ['PureWater', 'Golden Idol', 'MawBank', 'PreservedInsect', 'MealTicket', 'CloakClasp'], 'max_hp': 74, 'entering_hp': 37, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Hexaghost', 'potion_used': False, 'floor': 16, 'damage_taken': 9},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'FollowUp', 'PathToVictory', 'ReachHeaven', 'DeceiveReality', 'ClearTheMind', 'Wireheading', 'Wish'], 'relics': ['PureWater', 'Golden Idol', 'MawBank', 'PreservedInsect', 'MealTicket', 'CloakClasp', 'SlaversCollar'], 'max_hp': 74, 'entering_hp': 63, 'character': 'WATCHER', 'ascension': 20, 'enemies': '3 Byrds', 'potion_used': False, 'floor': 18, 'damage_taken': 40},
#         {'cards': ['Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'FollowUp', 'PathToVictory', 'ReachHeaven', 'DeceiveReality', 'ClearTheMind', 'Wireheading', 'Wish', 'Consecrate', 'Bite', 'Bite', 'Bite', 'Bite', 'Bite'], 'relics': ['PureWater', 'Golden Idol', 'MawBank', 'PreservedInsect', 'MealTicket', 'CloakClasp', 'SlaversCollar'], 'max_hp': 51, 'entering_hp': 23, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Chosen', 'potion_used': False, 'floor': 21, 'damage_taken': 2},
#         {'cards': ['Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'FollowUp', 'PathToVictory', 'ReachHeaven', 'DeceiveReality', 'ClearTheMind', 'Wireheading', 'Wish', 'Consecrate', 'Bite', 'Bite', 'Bite', 'Bite', 'Bite', 'ReachHeaven'], 'relics': ['PureWater', 'MawBank', 'PreservedInsect', 'MealTicket', 'CloakClasp', 'SlaversCollar', 'Bloody Idol'], 'max_hp': 51, 'entering_hp': 21, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Slavers', 'potion_used': True, 'floor': 23, 'damage_taken': 21}],
#        dtype=object),
#  array([{'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'PathToVictory'], 'relics': ['PureWater', 'PreservedInsect'], 'max_hp': 68, 'entering_hp': 45, 'character': 'WATCHER', 'ascension': 20, 'enemies': '2 Louse', 'potion_used': False, 'floor': 3, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'PathToVictory', 'Consecrate'], 'relics': ['PureWater', 'PreservedInsect', 'Gremlin Horn'], 'max_hp': 73, 'entering_hp': 32, 'character': 'WATCHER', 'ascension': 20, 'enemies': '3 Sentries', 'potion_used': False, 'floor': 7, 'damage_taken': 12},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'PathToVictory', 'Consecrate', 'FollowUp'], 'relics': ['PureWater', 'PreservedInsect', 'Gremlin Horn', 'Dream Catcher'], 'max_hp': 73, 'entering_hp': 20, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Small Slimes', 'potion_used': False, 'floor': 8, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'PathToVictory', 'Consecrate', 'FollowUp', 'FollowUp'], 'relics': ['PureWater', 'PreservedInsect', 'Gremlin Horn', 'Dream Catcher', 'Old Coin'], 'max_hp': 73, 'entering_hp': 20, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Gremlin Nob', 'potion_used': False, 'floor': 10, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'PathToVictory', 'Consecrate', 'FollowUp', 'FollowUp', 'CarveReality', 'Meditate', 'LikeWater', 'ClearTheMind', 'Consecrate'], 'relics': ['PureWater', 'PreservedInsect', 'Gremlin Horn', 'Dream Catcher', 'Old Coin', 'Centennial Puzzle'], 'max_hp': 73, 'entering_hp': 20, 'character': 'WATCHER', 'ascension': 20, 'enemies': '3 Louse', 'potion_used': False, 'floor': 12, 'damage_taken': 10},
#         {'cards': ['Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'PathToVictory', 'Consecrate', 'FollowUp', 'FollowUp', 'CarveReality', 'Meditate', 'LikeWater', 'ClearTheMind', 'Consecrate', 'BowlingBash'], 'relics': ['PureWater', 'PreservedInsect', 'Gremlin Horn', 'Dream Catcher', 'Old Coin', 'Centennial Puzzle'], 'max_hp': 73, 'entering_hp': 10, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Blue Slaver', 'potion_used': False, 'floor': 13, 'damage_taken': 8},
#         {'cards': ['Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'PathToVictory', 'Consecrate', 'FollowUp', 'FollowUp', 'CarveReality', 'Meditate', 'LikeWater', 'ClearTheMind', 'Consecrate', 'BowlingBash', 'Wireheading'], 'relics': ['PureWater', 'PreservedInsect', 'Gremlin Horn', 'Dream Catcher', 'Old Coin', 'Centennial Puzzle'], 'max_hp': 73, 'entering_hp': 2, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Lagavulin', 'potion_used': True, 'floor': 14, 'damage_taken': 2}],
#        dtype=object),
#  array([{'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'JustLucky'], 'relics': ['PureWater'], 'max_hp': 68, 'entering_hp': 57, 'character': 'WATCHER', 'ascension': 20, 'enemies': '2 Louse', 'potion_used': False, 'floor': 2, 'damage_taken': 5},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'JustLucky', 'CarveReality'], 'relics': ['PureWater', 'Golden Idol'], 'max_hp': 68, 'entering_hp': 29, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Cultist', 'potion_used': False, 'floor': 5, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'JustLucky', 'CarveReality', 'FlyingSleeves'], 'relics': ['PureWater', 'Golden Idol'], 'max_hp': 68, 'entering_hp': 29, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Lagavulin', 'potion_used': False, 'floor': 7, 'damage_taken': 8},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'JustLucky', 'CarveReality', 'FlyingSleeves', 'BowlingBash'], 'relics': ['PureWater', 'Golden Idol', 'Akabeko', 'Blood Vial'], 'max_hp': 68, 'entering_hp': 21, 'character': 'WATCHER', 'ascension': 20, 'enemies': '3 Sentries', 'potion_used': False, 'floor': 11, 'damage_taken': 4},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'JustLucky', 'CarveReality', 'FlyingSleeves', 'BowlingBash', 'ThirdEye'], 'relics': ['PureWater', 'Golden Idol', 'Akabeko', 'Blood Vial', 'Pen Nib'], 'max_hp': 68, 'entering_hp': 17, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Looter', 'potion_used': False, 'floor': 12, 'damage_taken': 0},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'JustLucky', 'CarveReality', 'FlyingSleeves', 'BowlingBash', 'ThirdEye'], 'relics': ['PureWater', 'Golden Idol', 'Akabeko', 'Blood Vial', 'Pen Nib', 'Vajra'], 'max_hp': 68, 'entering_hp': 17, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'Exordium Thugs', 'potion_used': False, 'floor': 14, 'damage_taken': -2},
#         {'cards': ['Strike_P', 'Strike_P', 'Strike_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Defend_P', 'Eruption', 'Vigilance', 'AscendersBane', 'JustLucky', 'CarveReality', 'FlyingSleeves', 'BowlingBash', 'ThirdEye', 'EmptyFist'], 'relics': ['PureWater', 'Golden Idol', 'Akabeko', 'Blood Vial', 'Pen Nib', 'Vajra'], 'max_hp': 68, 'entering_hp': 19, 'character': 'WATCHER', 'ascension': 20, 'enemies': 'The Guardian', 'potion_used': False, 'floor': 16, 'damage_taken': 19}],
#        dtype=object)]

# %%
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.feature_extraction.text import CountVectorizer

cv_enemies = CountVectorizer()
mlb_relics = MultiLabelBinarizer()
cv_cards = CountVectorizer()

# %%
card_list,relic_list,enemy_list,floor_list,damage_list,hp_list  = [],[],[],[],[],[]

for run in watcher_data:
    for floor in run:
        if(floor["entering_hp"]!=0):
            card_list.append(" ".join((floor["cards"])))
            relic_list.append((floor["relics"]))    
            enemy_list.append(" ".join((floor["enemies"])))
            floor_list.append(floor["floor"])
            damage_list.append(floor["damage_taken"])
            hp_list.append(floor["entering_hp"])

# %%
card_values = cv_cards.fit_transform(card_list).toarray()
relic_values = mlb_relics.fit_transform(relic_list)
enemy_values = cv_enemies.fit_transform(enemy_list).toarray()

# %%
X = []
for i in range(len(card_list)):
    features =  np.concatenate([card_values[i],relic_values[i],enemy_values[i],[floor_list[i]],[hp_list[i]]])
    X.append(features)
y = damage_list

# %% [markdown]
# **Step 5:** Train the Multilayer Perceptron Model

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=1)

# %% [markdown]
# **Step 6:** Hyperparameter Tuning <br /> <br />
# Note: these cells will take a while to run, so running these cells can be bypassed by accessing the pickled data at **Step 8**

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_val_score

# %%
param_1 = {
    'activation': ['relu', 'tanh', 'logistic'],
    'alpha': [1,0.1,0.01,0.001,0.0001]

}
param_2 = {
    'learning_rate_init': [0.001,0.01,0.1,0.2,0.3],
    'learning_rate': ['constant', 'invscaling', 'adaptive']
}

# %%
mlp = MLPRegressor(random_state=1, max_iter=10**6)
search = RandomizedSearchCV(mlp,param_1,scoring='neg_mean_squared_error',cv=5)
search_result=search.fit(X_train,y_train)
search_result.best_params_

# %%
mlp2 = MLPRegressor(random_state=1,activation = "relu", alpha = 0.1, max_iter=10**6)
search2 = RandomizedSearchCV(mlp2,param_2,scoring='neg_mean_squared_error',cv=5)
search2_result=search2.fit(X_train,y_train)
search2_result.best_params_

# %% [markdown]
# **Step 7:** Measure Performance: Using K-fold Validation, and Test Set Predictions

# %%
sizes = [100,200,(100,100),(200,200),(200,200,200),(100,200,100),(200,100,200),(100,200,200)]
scores = []
scores_test =[]

# %%
for size in sizes:
    mlp3 = MLPRegressor(random_state=1, hidden_layer_sizes = size, activation = "relu", alpha = 0.1,learning_rate_init= 0.01, learning_rate ="adaptive",max_iter=10**6)
    sc = cross_val_score(mlp3, X_train, y_train, scoring = "neg_mean_squared_error",cv=5)
    scores.append(np.average(sc))
    
    model = mlp3.fit(X_train, y_train)
    predictions = model.predict(X_test)
    mse = np.average((predictions - y_test)**2)
    scores_test.append(mse)

# %%
reg= [10,1,0.1,0.01,0.001,0.0001,0.00001]
reg_scores = []
reg_scores_test =[]

# %%
for val in reg:
    mlp4 = MLPRegressor(random_state=1,  alpha= val, activation = "relu", hidden_layer_sizes = (100,200,200),learning_rate_init= 0.01, learning_rate ="adaptive",max_iter=10**6)
    sc = cross_val_score(mlp4, X_train, y_train, scoring = "neg_mean_squared_error",cv=5)
    reg_scores.append(np.average(sc))
    
    model = mlp4.fit(X_train, y_train)
    predictions = model.predict(X_test)
    mse = np.average((predictions - y_test)**2)
    reg_scores_test.append(mse)

# %%
import pickle

pickle.dump([search_result,search2_result,scores,reg_scores,reg,sizes,scores_test,reg_scores_test],open('save.p', 'wb'))

# %% [markdown]
# **Step 8:** Organize the Results

# %%
import pickle
trial1,trial2,trial3,trial4,reg,sizes,scores_test,reg_scores_test = pickle.load(open( "save.p", "rb" ))

# %%
trial1.best_params_

# %%
trial2.best_params_

# %%
sizes[np.argmax(trial3)]

# %%
layers_data = {"Hidden Layer Sizes":sizes,"Mean Squared Error":-np.array(scores)}
df1 = pd.DataFrame(layers_data)

# %%
regularization_data = {"Regularization Value":reg,"Mean Squared Error":-np.array(reg_scores)}
df2 = pd.DataFrame(layers_data)

# %%
layers_test = {"Hidden Layer Sizes":sizes,"Mean Squared Error":scores_test}
df3 = pd.DataFrame(layers_test)

# %%
regularization_test = {"Regularization Value":reg,"Mean Squared Error":reg_scores_test}
df4 = pd.DataFrame(regularization_test)

# %% [markdown]
# **Step 9:** Evaluate the Final Model

# %%
mlp_final = MLPRegressor(random_state=1,  alpha= 0.1, activation = "relu", hidden_layer_sizes = (100,200,200),learning_rate_init= 0.01, learning_rate ="adaptive",max_iter=10**6)
final_fold = cross_val_score(mlp_final, X_train, y_train, scoring = "neg_mean_squared_error",cv=5)

# %%
fold_score = np.average(-final_fold)
fold_score

# %%
model = mlp_final.fit(X_train, y_train)
predictions = model.predict(X_test)
mse = np.average((predictions - y_test)**2)
mse

# %%
regularization_test = {"L2 Regularization":[0.1],"Activation":["Relu"],"Hidden Layers":[(100,200,200)],"Learning Rate":["adaptive"],"Init. Rate":[.01],"K-fold (MSE)":[fold_score],"Test Set Error (MSE)":[mse]}
df4 = pd.DataFrame(regularization_test)
df4

# %% [markdown]
# **Results and Analysis**

# %% [markdown]
# Slay the Spire is a highly complex card game with an extremely large number of combinations of cards,relics, and enemies. Furthermore, no card operates in a vacuum, rather they each interact with different relics and enemies in unique ways. Therefore, one of my primary concerns when designing a machine learning algorithm was that my algorithm would be unable to learn these underlying patterns in the data and would instead “memorize” the data in the training set, effectively overfitting to this set. Therefore, when optimizing the hyperparameters in my model, I emphasized testing different values for L2 regularization and hidden layers sizes. By using L2 regularization I could impose a greater penalty for higher weight coefficients, thus reducing overfitting. Furthermore, I wanted to be able to reduce the number of hidden nodes in the model, since  creating an overly complex model with too many nodes would generalize poorly to unseen data.

# %% [markdown]
# Estimating the Performace of the Models on Unseen Data Using 5-Fold Cross Validation

# %%
df1

# %%
df2

# %% [markdown]
# The tables above demonstrate the performance of the regression models based on different regularization values and numbers of hidden nodes. The models are scored by using 5-fold validation to estimate their performance on unseen data. These trials indicate the best configuration for the hidden layer is (100,200,200), meaning 100 nodes in the 1st layer, 200 nodes in the 2nd and 3rd layers. This configuration is complex, with both a significant amount of nodes and layers. However, the 1st layer is small when compared to the size of the feature vector (267). This indicates information/complexity is lost when moving from the input layer to the first layer, which could contribute to the lower level of overfitting. The best choice among the given regularization values is 0.1. This implies that regularization values of 10 and 1 may impose too steep a penalty on the training model, resulting in an overly simplified model.

# %% [markdown]
# Evaluating Model Performance on the Test Set:

# %%
df3

# %%
df4

# %% [markdown]
# The final trial (shown above), tests the estimates made using the 5-fold validation by testing the models (using different values of L2 and hidden layers), on the actual test set. These results differ from the expectations, of all the hidden layer configurations, (100,200,200) performed second worst, with an MSE of 19.40. Additionally, the L2 value of 0.1 performed worst among these tests, whereas .001 performed the best, with an MSE of 16.41.

# %% [markdown]
# **Opportunities for Future Investigation**
#
# The discrepancies in performance in the two trials, K-fold validation and test, makes me believe that I can improve the model and reduce its variability by adding more data points to the set. The largest data set available when I started the project contained 1216 usable data points. However, an update released last month has made data for over 77 million new games easily accessible. This would provide an opportunity to explore how new data would affect my model.

# %% [markdown]
# **Implications**
#
# Machine learning algorithms have gained notoriety for their ability to learn traditional strategy games such as Chess or Go and beat highly-skilled human opponents. However, AI served not only to compete against opponents, but it also provided a tool for players to better understand the game. For the card/strategy video game industry, machine learning could lead to similar advancements. For newer players, it could help identify the underlying strategies and concepts of the game. Even for experienced players, ML algorithms can reveal innovative and unconventional ways of playing games.

# %% [markdown]
# **References** <br/>
# https://spirelogs.com/ - For gathering raw data
#
#
# https://towardsdatascience.com/bringing-deep-neural-networks-to-slay-the-spire-a2971d5a5115
# This site helped me figure out the strategy for converting card/relics/enemies information into feature values. I apted this method, but using different encoding methods, different choices for features, and I computed different target values.
